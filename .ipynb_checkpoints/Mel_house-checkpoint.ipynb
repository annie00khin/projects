# %% [markdown]
# ## Overview

# %% [markdown]
# #### This project is to analyse the house pricing in melbourne and related features

# %% [markdown]
# #### The objective of this notebook is to analyze the data of melbourne housing prices and its related features, and to be able to conclude the relationships in well performed model. To summarize, the goals of this notebook are to conclude:
# >**_1. The model that explains the pricing by its related features_**
#
# >**_2. The melbourne housing markets trend between 2016-2017._**
#
# #### The goals are expected to meet common interests of certain stakeholders(Buyers&Sellers, Bank, Government, Agents and general public).
# #### This notebook will perform data preprocession before stepping into the features analyzing and model building. To achieve the goals, this notebook will examine features which obviously related to the housing prices. According to the domain knowledge, it will primarily focus on the the features such as suburb, land size, building area, bedrooms and bathrooms. Various visualization will be used for better presentation of data throughout the notebook.
#
# #### This notebook is designed as sections of short and long answered questions, which helps to deduct the useful informations for the goals proposed above.

# %%
## Import library to support the analysis
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## _Section 1: Data preprocession_

# %% [markdown]
# #### Check the data(scan the head and tail)

# %%
## Read in file
melb_house = pd.read_csv('file/melb_data.csv')
melb_house.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# 0        NaN        Yarra  -37.7996    144.9984  Northern Metropolitan
# 1     1900.0        Yarra  -37.8079    144.9934  Northern Metropolitan
# 2     1900.0        Yarra  -37.8093    144.9944  Northern Metropolitan
# 3        NaN        Yarra  -37.7969    144.9969  Northern Metropolitan
# 4     2014.0        Yarra  -37.8072    144.9941  Northern Metropolitan
#
#   Propertycount
# 0        4019.0
# 1        4019.0
# 2        4019.0
# 3        4019.0
# 4        4019.0
#
# [5 rows x 21 columns]

# %%
melb_house.tail()
# Out:
#               Suburb        Address  Rooms Type      Price Method   SellerG  \
# 13575  Wheelers Hill   12 Strada Cr      4    h  1245000.0      S     Barry
# 13576   Williamstown  77 Merrett Dr      3    h  1031000.0     SP  Williams
# 13577   Williamstown    83 Power St      3    h  1170000.0      S     Raine
# 13578   Williamstown   96 Verdon St      4    h  2500000.0     PI   Sweeney
# 13579     Yarraville     6 Agnes St      4    h  1285000.0     SP   Village
#
#              Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# 13575  26/08/2017      16.7    3150.0  ...       2.0  2.0     652.0
# 13576  26/08/2017       6.8    3016.0  ...       2.0  2.0     333.0
# 13577  26/08/2017       6.8    3016.0  ...       2.0  4.0     436.0
# 13578  26/08/2017       6.8    3016.0  ...       1.0  5.0     866.0
# 13579  26/08/2017       6.3    3013.0  ...       1.0  1.0     362.0
#
#        BuildingArea  YearBuilt  CouncilArea Lattitude  Longtitude  \
# 13575           NaN     1981.0          NaN -37.90562   145.16761
# 13576         133.0     1995.0          NaN -37.85927   144.87904
# 13577           NaN     1997.0          NaN -37.85274   144.88738
# 13578         157.0     1920.0          NaN -37.85908   144.89299
# 13579         112.0     1920.0          NaN -37.81188   144.88449
#
#                        Regionname Propertycount
# 13575  South-Eastern Metropolitan        7392.0
# 13576        Western Metropolitan        6380.0
# 13577        Western Metropolitan        6380.0
# 13578        Western Metropolitan        6380.0
# 13579        Western Metropolitan        6543.0
#
# [5 rows x 21 columns]

# %% [markdown]
# #### Check the datatype to understand the value in each column

# %%
## Check data info for each column
melb_house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         13580 non-null  object
#  1   Address        13580 non-null  object
#  2   Rooms          13580 non-null  int64
#  3   Type           13580 non-null  object
#  4   Price          13580 non-null  float64
#  5   Method         13580 non-null  object
#  6   SellerG        13580 non-null  object
#  7   Date           13580 non-null  object
#  8   Distance       13580 non-null  float64
#  9   Postcode       13580 non-null  float64
#  10  Bedroom2       13580 non-null  float64
#  11  Bathroom       13580 non-null  float64
#  12  Car            13518 non-null  float64
#  13  Landsize       13580 non-null  float64
#  14  BuildingArea   7130 non-null   float64
#  15  YearBuilt      8205 non-null   float64
#  16  CouncilArea    12211 non-null  object
#  17  Lattitude      13580 non-null  float64
#  18  Longtitude     13580 non-null  float64
#  19  Regionname     13580 non-null  object
#  20  Propertycount  13580 non-null  float64
# dtypes: float64(12), int64(1), object(8)
# memory usage: 2.2+ MB

# %% [markdown]
# #### Do we have missing values in the data, if so, where are these missing values locating at?

# %%
## Check missing values
melb_house.isnull().sum()
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price               0
# Method              0
# SellerG             0
# Date                0
# Distance            0
# Postcode            0
# Bedroom2            0
# Bathroom            0
# Car                62
# Landsize            0
# BuildingArea     6450
# YearBuilt        5375
# CouncilArea      1369
# Lattitude           0
# Longtitude          0
# Regionname          0
# Propertycount       0
# dtype: int64

# %% [markdown]
# ##### Based on our domain knowledge, the missing value in building area and built year requires further reference to be able to fill them, which is out of scope in the data available here.
#
# ##### The council area can be filled with cross matching the full column 'Suburb'. This column can still be taken into consideration of pricing analysis if there is no more missing values after filled.

# %% [markdown]
# #### Filling the missing values in CouncilArea

# %%
melb_house['CouncilArea']=melb_house.loc[melb_house['Suburb']]

# %% [markdown]
# #### Is there still missing value in council area after fillind?

# %%
melb_house['CouncilArea'].isnull().sum()

# %% [markdown]
# #### What are the values in column car?

# %%
## Check the values in Column Car
melb_house['Car'].unique()
# Out:
# array([ 1.,  0.,  2.,  6.,  5.,  4.,  3.,  8.,  7.,  9., 10., nan])

# %% [markdown]
# #### what the house type of the property that have missing car values?

# %%
pd.set_option('display.max_rows', None)
## prepared dataframe
car_na = melb_house[melb_house['Car'].isna()][['Car', 'Type']]

# %%
car_na.groupby(['Type'])

# %%
## apply pie chart to visualize the house type without value in car column. 
car_grouped = car_na.groupby('Type').size()
car_grouped.plot(kind='pie', subplots = True, figsize=(8,8))
plt.title('Pie chart of the house type without value in column Car')
plt.ylabel('')
plt.show()

# %% [markdown]
# #### We can conclude that the missing values in car include property types of both unit and house. Based on the domain knowledge, the house has at least the street parking space, we can fill them as 1 car space. As for unit, no reference can be made without supporting data, we can use 0 to fill here as it is a very low portion in this data, also because the car space does not alter the pricing of unit much based on the domain knowledge.

# %% [markdown]
# #### Filling the missing value in column 'Car'

# %%
melb_house.loc[melb_house['Type'] = 'h' && melb_house['Car'].isna(), 'Car']=1
melb_house.loc[melb_house['Type'] = 'u' && melb_house['Car'].isna(), 'Car']=0

# %% [markdown]
# #### How many housing types we have and how are they distributed?

# %%
sns.countplot(x=melb_house['Type'])
# Out:
# <AxesSubplot:xlabel='Type', ylabel='count'>

# %% [markdown]
# #### How is the property distributed based on suburb?

# %%
sub_count = melb_house.groupby(['Suburb'])['Address'].count().reset_index(name='count').sort_values('count', ascending=False)
sub_count
# Out:
#                  Suburb  count
# 236           Reservoir    359
# 237            Richmond    260
# 30       Bentleigh East    249
# 234             Preston    239
# 46            Brunswick    222
# 118            Essendon    220
# 259         South Yarra    202
# 136           Glen Iris    195
# 147            Hawthorn    191
# 80               Coburg    190
# 217           Northcote    188
# 41             Brighton    186
# 170                 Kew    177
# 22         Balwyn North    171
# 229         Pascoe Vale    171
# 313          Yarraville    164
# 266            St Kilda    162
# 138             Glenroy    159
# 232      Port Melbourne    153
# 202        Moonee Ponds    149
# 63             Carnegie    146
# 282           Thornbury    139
# 29            Bentleigh    139
# 42        Brighton East    138
# 212             Newport    137
# 127           Footscray    132
# 58           Camberwell    132
# 114              Elwood    131
# 12           Ascot Vale    130
# 144             Hampton    130
# 273        Surrey Hills    125
# 233             Prahran    123
# 166         Keilor East    121
# 148       Hawthorn East    119
# 169          Kensington    117
# 185        Malvern East    117
# 103           Doncaster    116
# 270            Sunshine    111
# 48       Brunswick West    110
# 305        Williamstown    107
# 21               Balwyn    107
# 299      West Footscray    105
# 122             Fawkner    102
# 283              Toorak    100
# 160             Ivanhoe     98
# 186         Maribyrnong     96
# 11             Armadale     95
# 183           Maidstone     94
# 125       Fitzroy North     93
# 279   Templestowe Lower     92
# 47       Brunswick East     88
# 272       Sunshine West     86
# 257     South Melbourne     85
# 55              Burwood     84
# 225              Ormond     83
# 213             Niddrie     82
# 209         Murrumbeena     82
# 215     North Melbourne     81
# 152  Heidelberg Heights     78
# 153     Heidelberg West     76
# 7                Altona     74
# 18     Avondale Heights     74
# 49              Bulleen     71
# 4           Albert Park     69
# 271      Sunshine North     68
# 184             Malvern     67
# 2          Airport West     67
# 82          Collingwood     65
# 203           Moorabbin     64
# 220            Oak Park     63
# 267          Strathmore     63
# 142            Hadfield     62
# 126          Flemington     62
# 253              Seddon     62
# 111         Elsternwick     61
# 244             Rosanna     61
# 13            Ashburton     60
# 307             Windsor     60
# 38             Box Hill     59
# 124             Fitzroy     59
# 223      Oakleigh South     58
# 79         Clifton Hill     57
# 207      Mount Waverley     57
# 0            Abbotsford     56
# 81         Coburg North     56
# 9          Altona North     56
# 60           Canterbury     54
# 117              Epping     52
# 296            Watsonia     52
# 151          Heidelberg     51
# 61              Carlton     51
# 298            Werribee     50
# 171            Kew East     49
# 62        Carlton North     48
# 70      Caulfield South     47
# 84          Craigieburn     47
# 221            Oakleigh     47
# 189           Melbourne     46
# 39            Braybrook     46
# 74           Cheltenham     46
# 14              Ashwood     46
# 137       Glen Waverley     45
# 1            Aberfeldie     44
# 121           Fairfield     43
# 196           Mill Park     43
# 180               Lalor     42
# 290            Viewbank     41
# 260           Southbank     41
# 104      Doncaster East     41
# 5                Albion     41
# 156    Hoppers Crossing     38
# 269             Sunbury     38
# 140       Greensborough     36
# 51             Bundoora     36
# 69      Caulfield North     35
# 71            Chadstone     35
# 157          Hughesdale     35
# 199         Mont Albert     34
# 176          Kingsville     34
# 195         Middle Park     34
# 6            Alphington     34
# 88              Croydon     33
# 300      West Melbourne     31
# 228           Parkville     31
# 197             Mitcham     30
# 281          Thomastown     29
# 208            Mulgrave     29
# 261           Spotswood     29
# 20            Balaclava     27
# 154             Highett     27
# 120       Essendon West     26
# 193             Mentone     26
# 302       Wheelers Hill     26
# 87             Cremorne     25
# 161        Ivanhoe East     25
# 145        Hampton East     25
# 112              Eltham     25
# 264           St Albans     25
# 248         Sandringham     25
# 162              Jacana     25
# 227            Parkdale     24
# 129           Frankston     24
# 311           Yallambie     24
# 139           Gowanbrae     24
# 108           Eaglemont     23
# 43         Broadmeadows     23
# 168         Keilor Park     22
# 256    South Kingsville     22
# 293      Wantirna South     22
# 277       Taylors Lakes     22
# 119      Essendon North     22
# 128         Forest Hill     22
# 123      Ferntree Gully     22
# 109      East Melbourne     22
# 258        South Morang     21
# 101     Dingley Village     21
# 33            Blackburn     21
# 134      Gladstone Park     20
# 239            Ringwood     20
# 219          Nunawading     20
# 306  Williamstown North     19
# 278         Templestowe     19
# 163              Kealba     19
# 205          Mordialloc     18
# 27            Beaumaris     18
# 155            Hillside     18
# 191        Melton South     18
# 188      Meadow Heights     17
# 141           Greenvale     17
# 200         Montmorency     17
# 135         Glen Huntly     17
# 56         Burwood East     16
# 28            Bellfield     16
# 131     Frankston South     16
# 150           Heathmont     16
# 94      Dandenong North     16
# 246       Roxburgh Park     15
# 165        Keilor Downs     15
# 96            Deer Park     14
# 37              Boronia     14
# 23            Bayswater     14
# 301         Westmeadows     14
# 251             Seaford     14
# 288             Vermont     14
# 34      Blackburn North     14
# 289       Vermont South     13
# 31              Berwick     13
# 105             Donvale     13
# 286         Tullamarine     13
# 175           Kingsbury     13
# 77              Clayton     13
# 93            Dandenong     13
# 231          Point Cook     13
# 113        Eltham North     13
# 190              Melton     12
# 67            Caulfield     12
# 292            Wantirna     12
# 32           Black Rock     12
# 35      Blackburn South     12
# 66         Carrum Downs     12
# 204         Mooroolbark     12
# 240       Ringwood East     12
# 214          Noble Park     12
# 222       Oakleigh East     11
# 172         Keysborough     11
# 78        Clayton South     11
# 64     Caroline Springs     11
# 284          Travancore     10
# 297      Watsonia North     10
# 275             Tarneit     10
# 241      Ringwood North     10
# 245            Rowville     10
# 262          Springvale      9
# 110           Edithvale      9
# 45             Brooklyn      9
# 164              Keilor      9
# 308             Wollert      9
# 68       Caulfield East      9
# 194              Mernda      9
# 242           Ripponlea      9
# 65               Carrum      9
# 24      Bayswater North      8
# 249            Scoresby      8
# 40           Briar Hill      8
# 187            McKinnon      8
# 133            Gisborne      8
# 192         Melton West      8
# 57             Cairnlea      7
# 90        Croydon North      7
# 107             Doveton      7
# 210        Narre Warren      7
# 15            Aspendale      7
# 158         Huntingdale      7
# 52              Burnley      7
# 276        Taylors Hill      7
# 181          Langwarrin      6
# 99        Diamond Creek      6
# 268  Strathmore Heights      6
# 97              Delahey      6
# 92               Dallas      6
# 252            Seaholme      6
# 106              Doreen      6
# 132          Gardenvale      6
# 3             Albanvale      6
# 8        Altona Meadows      6
# 274            Sydenham      5
# 285           Truganina      5
# 294          Warrandyte      5
# 143              Hallam      5
# 174          Kings Park      5
# 72              Chelsea      5
# 182        Lower Plenty      5
# 116     Endeavour Hills      5
# 235        Princes Hill      5
# 98             Derrimut      5
# 146        Hampton Park      4
# 173             Kilsyth      4
# 280           The Basin      4
# 59        Campbellfield      4
# 76             Clarinda      4
# 16    Aspendale Gardens      4
# 89        Croydon Hills      4
# 36             Bonbeach      4
# 83             Coolaroo      4
# 73      Chelsea Heights      4
# 310        Wyndham Vale      4
# 177           Knoxfield      4
# 179           Kurunjang      4
# 130     Frankston North      4
# 265           St Helena      3
# 85           Cranbourne      3
# 102           Docklands      3
# 10               Ardeer      3
# 54     Burnside Heights      3
# 250            Seabrook      3
# 263    Springvale South      3
# 226            Pakenham      3
# 218        Notting Hill      3
# 304    Williams Landing      2
# 159         Hurstbridge      2
# 95             Deepdene      2
# 295           Waterways      2
# 206        Mount Evelyn      2
# 25         Beaconsfield      2
# 254              Silvan      2
# 86     Cranbourne North      2
# 167        Keilor Lodge      2
# 216    North Warrandyte      2
# 75       Chirnside Park      2
# 178             Kooyong      2
# 53             Burnside      2
# 255                Skye      2
# 100        Diggers Rest      2
# 303          Whittlesea      1
# 309          Wonga Park      1
# 115             Emerald      1
# 312          Yarra Glen      1
# 238      Riddells Creek      1
# 230            Plumpton      1
# 44           Brookfield      1
# 149         Healesville      1
# 211        New Gisborne      1
# 291              Wallan      1
# 50         Bullengarook      1
# 287               Upwey      1
# 201            Montrose      1
# 198             Monbulk      1
# 91        Croydon South      1
# 243            Rockbank      1
# 17              Attwood      1
# 26   Beaconsfield Upper      1
# 19        Bacchus Marsh      1
# 247           Sandhurst      1
# 224             Officer      1

# %%
sns.set_theme(style="darkgrid")
sns.countplot(x=melb_house['Method'])
# Out:
# <AxesSubplot:xlabel='Method', ylabel='count'>

# %% [markdown]
# ## _Section 2: Features analyzing_

# %% [markdown]
# ## _Section 3: Model building_

# %% [markdown]
# ## _Model Interpretation_

# %% [markdown]
# ## _Melbourne housing market trend(16-17)_
