# %% [markdown]
# ## This project is to analyse the house pricing in melbourne and related features

# %% [markdown]
# #### The objective of this notebook is to analyze the data of melbourne housing prices and its related features available through questions and answers. The code will produce the answers to questions asked in each section.
#
# #### Through the questions proposed and answered, this notebook is expected to conclude the effects of certain features on the house pricing, which is the common interest of the stakeholders(Buyer&sellers, Bank, Government, Agents and General public).
#
# #### In addition, this notebook will also conclude the trend of housing market between 2016 and 2017 from the data available here.

# %%
## Import library to support the analysis
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# #### Check the data(scan the head and tail)

# %%
## Read in file
melb_house = pd.read_csv('file/melb_data.csv')
melb_house.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# 0        NaN        Yarra  -37.7996    144.9984  Northern Metropolitan
# 1     1900.0        Yarra  -37.8079    144.9934  Northern Metropolitan
# 2     1900.0        Yarra  -37.8093    144.9944  Northern Metropolitan
# 3        NaN        Yarra  -37.7969    144.9969  Northern Metropolitan
# 4     2014.0        Yarra  -37.8072    144.9941  Northern Metropolitan
#
#   Propertycount
# 0        4019.0
# 1        4019.0
# 2        4019.0
# 3        4019.0
# 4        4019.0
#
# [5 rows x 21 columns]

# %%
melb_house.tail()
# Out:
#               Suburb        Address  Rooms Type      Price Method   SellerG  \
# 13575  Wheelers Hill   12 Strada Cr      4    h  1245000.0      S     Barry
# 13576   Williamstown  77 Merrett Dr      3    h  1031000.0     SP  Williams
# 13577   Williamstown    83 Power St      3    h  1170000.0      S     Raine
# 13578   Williamstown   96 Verdon St      4    h  2500000.0     PI   Sweeney
# 13579     Yarraville     6 Agnes St      4    h  1285000.0     SP   Village
#
#              Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# 13575  26/08/2017      16.7    3150.0  ...       2.0  2.0     652.0
# 13576  26/08/2017       6.8    3016.0  ...       2.0  2.0     333.0
# 13577  26/08/2017       6.8    3016.0  ...       2.0  4.0     436.0
# 13578  26/08/2017       6.8    3016.0  ...       1.0  5.0     866.0
# 13579  26/08/2017       6.3    3013.0  ...       1.0  1.0     362.0
#
#        BuildingArea  YearBuilt  CouncilArea Lattitude  Longtitude  \
# 13575           NaN     1981.0          NaN -37.90562   145.16761
# 13576         133.0     1995.0          NaN -37.85927   144.87904
# 13577           NaN     1997.0          NaN -37.85274   144.88738
# 13578         157.0     1920.0          NaN -37.85908   144.89299
# 13579         112.0     1920.0          NaN -37.81188   144.88449
#
#                        Regionname Propertycount
# 13575  South-Eastern Metropolitan        7392.0
# 13576        Western Metropolitan        6380.0
# 13577        Western Metropolitan        6380.0
# 13578        Western Metropolitan        6380.0
# 13579        Western Metropolitan        6543.0
#
# [5 rows x 21 columns]

# %% [markdown]
# #### Check the datatype to understand the value in each column

# %%
## Check data info for each column
melb_house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         13580 non-null  object
#  1   Address        13580 non-null  object
#  2   Rooms          13580 non-null  int64
#  3   Type           13580 non-null  object
#  4   Price          13580 non-null  float64
#  5   Method         13580 non-null  object
#  6   SellerG        13580 non-null  object
#  7   Date           13580 non-null  object
#  8   Distance       13580 non-null  float64
#  9   Postcode       13580 non-null  float64
#  10  Bedroom2       13580 non-null  float64
#  11  Bathroom       13580 non-null  float64
#  12  Car            13518 non-null  float64
#  13  Landsize       13580 non-null  float64
#  14  BuildingArea   7130 non-null   float64
#  15  YearBuilt      8205 non-null   float64
#  16  CouncilArea    12211 non-null  object
#  17  Lattitude      13580 non-null  float64
#  18  Longtitude     13580 non-null  float64
#  19  Regionname     13580 non-null  object
#  20  Propertycount  13580 non-null  float64
# dtypes: float64(12), int64(1), object(8)
# memory usage: 2.2+ MB

# %% [markdown]
# #### Do we have missing values in the data, if so, where are these missing values locating at?

# %%
## Check missing values
melb_house.isnull().sum()
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price               0
# Method              0
# SellerG             0
# Date                0
# Distance            0
# Postcode            0
# Bedroom2            0
# Bathroom            0
# Car                62
# Landsize            0
# BuildingArea     6450
# YearBuilt        5375
# CouncilArea      1369
# Lattitude           0
# Longtitude          0
# Regionname          0
# Propertycount       0
# dtype: int64

# %% [markdown]
# ##### Based on our domain knowledge, the missing value in building area and built year requires further reference to be able to fill them, which is out of scope in the data available here.
#
# ##### The council area can be filled with cross matching the full column 'Suburb'. This column can still be taken into consideration of pricing analysis if there is no more missing values after filled.

# %% [markdown]
# #### Fillind the missing values in CouncilArea

# %%
melb_house['CouncilArea']=melb_house.loc[melb_house['Suburb']]

# %% [markdown]
# #### Is there still missing value in council area after fillind?

# %%
melb_house['CouncilArea'].isnull().sum()

# %% [markdown]
# #### What are the values in column car?

# %%
## Check the values in Column Car
melb_house['Car'].unique()
# Out:
# array([ 1.,  0.,  2.,  6.,  5.,  4.,  3.,  8.,  7.,  9., 10., nan])

# %% [markdown]
# #### what the house type of the property that have missing car values?

# %%
pd.set_option('display.max_rows', None)
melb_house.loc[melb_house['Car'].isnull()][['Type', 'Car']]
# Out:
#       Type  Car
# 12221    h  NaN
# 12247    h  NaN
# 12259    h  NaN
# 12320    h  NaN
# 12362    h  NaN
# 12383    h  NaN
# 12397    h  NaN
# 12426    h  NaN
# 12462    h  NaN
# 12463    h  NaN
# 12464    h  NaN
# 12474    h  NaN
# 12489    h  NaN
# 12490    h  NaN
# 12497    h  NaN
# 12531    h  NaN
# 12606    h  NaN
# 12607    h  NaN
# 12608    h  NaN
# 12610    h  NaN
# 12611    h  NaN
# 12613    h  NaN
# 12633    h  NaN
# 12638    h  NaN
# 12723    h  NaN
# 12785    h  NaN
# 12805    h  NaN
# 12806    h  NaN
# 12815    h  NaN
# 12818    u  NaN
# 12819    h  NaN
# 12830    h  NaN
# 12841    h  NaN
# 12844    h  NaN
# 12884    h  NaN
# 12888    h  NaN
# 12929    h  NaN
# 12937    h  NaN
# 12975    h  NaN
# 12995    h  NaN
# 13048    h  NaN
# 13091    h  NaN
# 13097    h  NaN
# 13175    h  NaN
# 13177    h  NaN
# 13224    h  NaN
# 13225    h  NaN
# 13249    h  NaN
# 13253    h  NaN
# 13266    h  NaN
# 13289    h  NaN
# 13294    h  NaN
# 13297    h  NaN
# 13345    h  NaN
# 13372    u  NaN
# 13389    h  NaN
# 13460    h  NaN
# 13496    h  NaN
# 13508    h  NaN
# 13522    h  NaN
# 13524    h  NaN
# 13550    h  NaN

# %% [markdown]
# #### We can conclude that the missing values in car include property types of both unit and house. Based on the domain knowledge, the house has at least the street parking space, we can fill them as 1 car space. As for unit, no reference can be made without supporting data, we can use 0 to fill here as it is a very low portion in this data, also because the car space does not alter the pricing of unit much based on the domain knowledge.

# %% [markdown]
# ### Visualize the data to have a better understanding

# %% [markdown]
# #### How many housing types we have and how are they distributed?

# %%
sns.countplot(x=melb_house['Type'])
# Out:
# <AxesSubplot:xlabel='Type', ylabel='count'>

# %%
sub_count = melb_house.groupby(['Suburb'])['Address'].count().reset_index(name='count')
sub_count
# Out:
#            Suburb  count
# 0      Abbotsford     56
# 1      Aberfeldie     44
# 2    Airport West     67
# 3       Albanvale      6
# 4     Albert Park     69
# ..            ...    ...
# 309    Wonga Park      1
# 310  Wyndham Vale      4
# 311     Yallambie     24
# 312    Yarra Glen      1
# 313    Yarraville    164
#
# [314 rows x 2 columns]

# %%
sns.set_theme(style="darkgrid")
sns.countplot(x=melb_house['Method'])
# Out:
# <AxesSubplot:xlabel='Method', ylabel='count'>
