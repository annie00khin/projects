# %% [markdown]
# ## Overview

# %% [markdown]
# #### This project is to analyse the house pricing in melbourne and related features

# %% [markdown]
# #### The objective of this notebook is to analyze the data of melbourne housing prices and its related features, and to be able to conclude the relationships in well performed model. To summarize, the goals of this notebook are to conclude:
# >**_1. The model that explains the pricing by its related features_**
#
# >**_2. The melbourne housing markets trend between 2016-2017._**
#
# #### The goals are expected to meet common interests of certain stakeholders(Buyers&Sellers, Bank, Government, Agents and general public).
# #### This notebook will perform data preprocession before stepping into the features analyzing and model building. To achieve the goals, this notebook will examine features which obviously related to the housing prices. According to the domain knowledge, it will primarily focus on the the features such as suburb, land size, building area, bedrooms and bathrooms. Various visualization will be used for better presentation of data throughout the notebook.
#
# #### This notebook is designed as sections of short and long answered questions, which helps to deduct the useful informations for the goals proposed above.

# %%
## Import library to support the analysis
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
import squarify
import plotly.express as px

# %% [markdown]
# ## _Section 1: Data preprocession_

# %% [markdown]
# #### Check the data(scan the head and tail)

# %%
## Read in file
melb_house = pd.read_csv('file/melb_data.csv')
melb_house.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# 0        NaN        Yarra  -37.7996    144.9984  Northern Metropolitan
# 1     1900.0        Yarra  -37.8079    144.9934  Northern Metropolitan
# 2     1900.0        Yarra  -37.8093    144.9944  Northern Metropolitan
# 3        NaN        Yarra  -37.7969    144.9969  Northern Metropolitan
# 4     2014.0        Yarra  -37.8072    144.9941  Northern Metropolitan
#
#   Propertycount
# 0        4019.0
# 1        4019.0
# 2        4019.0
# 3        4019.0
# 4        4019.0
#
# [5 rows x 21 columns]

# %%
melb_house.tail()
# Out:
#               Suburb        Address  Rooms Type      Price Method   SellerG  \
# 13575  Wheelers Hill   12 Strada Cr      4    h  1245000.0      S     Barry
# 13576   Williamstown  77 Merrett Dr      3    h  1031000.0     SP  Williams
# 13577   Williamstown    83 Power St      3    h  1170000.0      S     Raine
# 13578   Williamstown   96 Verdon St      4    h  2500000.0     PI   Sweeney
# 13579     Yarraville     6 Agnes St      4    h  1285000.0     SP   Village
#
#              Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# 13575  26/08/2017      16.7    3150.0  ...       2.0  2.0     652.0
# 13576  26/08/2017       6.8    3016.0  ...       2.0  2.0     333.0
# 13577  26/08/2017       6.8    3016.0  ...       2.0  4.0     436.0
# 13578  26/08/2017       6.8    3016.0  ...       1.0  5.0     866.0
# 13579  26/08/2017       6.3    3013.0  ...       1.0  1.0     362.0
#
#        BuildingArea  YearBuilt  CouncilArea Lattitude  Longtitude  \
# 13575           NaN     1981.0          NaN -37.90562   145.16761
# 13576         133.0     1995.0          NaN -37.85927   144.87904
# 13577           NaN     1997.0          NaN -37.85274   144.88738
# 13578         157.0     1920.0          NaN -37.85908   144.89299
# 13579         112.0     1920.0          NaN -37.81188   144.88449
#
#                        Regionname Propertycount
# 13575  South-Eastern Metropolitan        7392.0
# 13576        Western Metropolitan        6380.0
# 13577        Western Metropolitan        6380.0
# 13578        Western Metropolitan        6380.0
# 13579        Western Metropolitan        6543.0
#
# [5 rows x 21 columns]

# %% [markdown]
# #### Check the datatype to understand the value in each column

# %%
## Check data info for each column
melb_house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         13580 non-null  object
#  1   Address        13580 non-null  object
#  2   Rooms          13580 non-null  int64
#  3   Type           13580 non-null  object
#  4   Price          13580 non-null  float64
#  5   Method         13580 non-null  object
#  6   SellerG        13580 non-null  object
#  7   Date           13580 non-null  object
#  8   Distance       13580 non-null  float64
#  9   Postcode       13580 non-null  float64
#  10  Bedroom2       13580 non-null  float64
#  11  Bathroom       13580 non-null  float64
#  12  Car            13518 non-null  float64
#  13  Landsize       13580 non-null  float64
#  14  BuildingArea   7130 non-null   float64
#  15  YearBuilt      8205 non-null   float64
#  16  CouncilArea    12211 non-null  object
#  17  Lattitude      13580 non-null  float64
#  18  Longtitude     13580 non-null  float64
#  19  Regionname     13580 non-null  object
#  20  Propertycount  13580 non-null  float64
# dtypes: float64(12), int64(1), object(8)
# memory usage: 2.2+ MB

# %% [markdown]
# #### Do we have missing values in the data, if so, where are these missing values locating at?

# %%
## Check missing values
melb_house.isnull().sum()
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price               0
# Method              0
# SellerG             0
# Date                0
# Distance            0
# Postcode            0
# Bedroom2            0
# Bathroom            0
# Car                62
# Landsize            0
# BuildingArea     6450
# YearBuilt        5375
# CouncilArea      1369
# Lattitude           0
# Longtitude          0
# Regionname          0
# Propertycount       0
# dtype: int64

# %% [markdown]
# ##### Based on our domain knowledge, the missing value in building area and built year requires further reference to be able to fill them, which is out of scope in the data available here.
#
# ##### The council area can be filled with cross matching the full column 'Suburb'. This column can still be taken into consideration of pricing analysis if there is no more missing values after filled.

# %% [markdown]
# #### Filling the missing values in CouncilArea

# %%
melb_house.loc[melb_house['CouncilArea'].isna()][['Suburb','CouncilArea']]
# Out:
#               Suburb CouncilArea
# 7584   Brighton East         NaN
# 10797      Reservoir         NaN
# 12213     Aberfeldie         NaN
# 12214         Albion         NaN
# 12215     Alphington         NaN
# ...              ...         ...
# 13575  Wheelers Hill         NaN
# 13576   Williamstown         NaN
# 13577   Williamstown         NaN
# 13578   Williamstown         NaN
# 13579     Yarraville         NaN
#
# [1369 rows x 2 columns]

# %%
melb_house.loc[melb_house['CouncilArea'].isna(), 'CouncilArea']= melb_house.loc[melb_house['suburb'], ]

# %% [markdown]
# #### Is there still missing value in council area after filling?

# %%
melb_house['CouncilArea'].isnull().sum()

# %% [markdown]
# #### What are the values in column car?

# %%
## Check the values in Column Car
melb_house['Car'].unique()
# Out:
# array([ 1.,  0.,  2.,  6.,  5.,  4.,  3.,  8.,  7.,  9., 10., nan])

# %%
car = melb_house['Car'].reset_index()
car.groupby('Car').agg('count')
# Out:
#       index
# Car
# 0.0    1026
# 1.0    5509
# 2.0    5591
# 3.0     748
# 4.0     506
# 5.0      63
# 6.0      54
# 7.0       8
# 8.0       9
# 9.0       1
# 10.0      3

# %% [markdown]
# #### what the house type of the property that have missing car values?

# %%
pd.set_option('display.max_rows', None)
## prepared dataframe
car_na = melb_house[melb_house['Car'].isna()][['Type']].reset_index()

# %%
car_na.groupby('Type').agg('count')
# Out:
#       index
# Type
# h        60
# u         2

# %%
postcode = melb_house['Postcode'].reset_index()
postcode.groupby('Postcode').agg('count').sort_values('index', ascending=False)
# Out:
#           index
# Postcode
# 3073.0      359
# 3020.0      306
# 3121.0      292
# 3040.0      290
# 3046.0      284
# 3165.0      249
# 3058.0      246
# 3163.0      245
# 3012.0      242
# 3072.0      239
# 3032.0      236
# 3204.0      230
# 3056.0      222
# 3141.0      202
# 3146.0      195
# 3011.0      194
# 3122.0      191
# 3015.0      188
# 3070.0      188
# 3186.0      186
# 3181.0      183
# 3031.0      179
# 3101.0      177
# 3084.0      176
# 3042.0      171
# 3044.0      171
# 3104.0      171
# 3081.0      170
# 3013.0      164
# 3182.0      162
# 3127.0      159
# 3188.0      155
# 3207.0      153
# 3068.0      150
# 3039.0      149
# 3071.0      139
# 3187.0      138
# 3124.0      132
# 3184.0      131
# 3145.0      126
# 3016.0      126
# 3079.0      123
# 3033.0      121
# 3123.0      119
# 3108.0      116
# 3055.0      110
# 3103.0      109
# 3147.0      106
# 3206.0      103
# 3060.0      102
# 3142.0      100
# 3166.0      100
# 3143.0       95
# 3107.0       92
# 3041.0       91
# 3057.0       88
# 3205.0       85
# 3125.0       84
# 3051.0       81
# 3018.0       80
# 3078.0       77
# 3185.0       76
# 3034.0       74
# 3150.0       71
# 3105.0       71
# 3144.0       69
# 3030.0       68
# 3066.0       65
# 3189.0       64
# 3087.0       62
# 3064.0       62
# 3128.0       59
# 3162.0       59
# 3065.0       59
# 3167.0       58
# 3043.0       57
# 3149.0       57
# 3025.0       56
# 3067.0       56
# 3195.0       55
# 3021.0       55
# 3126.0       54
# 3047.0       54
# 3054.0       53
# 3029.0       53
# 3076.0       52
# 3053.0       51
# 3102.0       49
# 3083.0       49
# 3088.0       47
# 3130.0       47
# 3000.0       46
# 3019.0       46
# 3192.0       46
# 3136.0       45
# 3082.0       43
# 3131.0       42
# 3075.0       42
# 3109.0       41
# 3006.0       41
# 3199.0       40
# 3038.0       39
# 3429.0       38
# 3095.0       38
# 3023.0       37
# 3037.0       36
# 3148.0       35
# 3161.0       35
# 3152.0       34
# 3003.0       31
# 3052.0       31
# 3193.0       30
# 3132.0       30
# 3134.0       30
# 3074.0       29
# 3175.0       29
# 3170.0       29
# 3135.0       28
# 3183.0       27
# 3190.0       27
# 3133.0       27
# 3194.0       26
# 3191.0       25
# 3172.0       24
# 3337.0       24
# 3085.0       24
# 3196.0       22
# 3002.0       22
# 3153.0       22
# 3156.0       22
# 3048.0       21
# 3752.0       21
# 3338.0       19
# 3106.0       19
# 3059.0       17
# 3094.0       17
# 3151.0       16
# 3168.0       16
# 3169.0       15
# 3754.0       15
# 3049.0       15
# 3198.0       14
# 3155.0       14
# 3111.0       13
# 3806.0       13
# 3201.0       12
# 3138.0       12
# 3174.0       12
# 3173.0       11
# 3178.0       10
# 3028.0        9
# 3750.0        9
# 3437.0        9
# 3197.0        9
# 3036.0        9
# 3171.0        9
# 3977.0        8
# 3179.0        8
# 3805.0        7
# 3177.0        7
# 3113.0        7
# 3910.0        6
# 3089.0        6
# 3802.0        5
# 3803.0        5
# 3093.0        5
# 3200.0        4
# 3976.0        4
# 3061.0        4
# 3137.0        4
# 3180.0        4
# 3154.0        4
# 3024.0        4
# 3810.0        3
# 3022.0        3
# 3008.0        3
# 3807.0        2
# 3099.0        2
# 3027.0        2
# 3116.0        2
# 3796.0        2
# 3427.0        2
# 3335.0        2
# 3795.0        2
# 3808.0        1
# 3809.0        1
# 3765.0        1
# 3793.0        1
# 3782.0        1
# 3777.0        1
# 3775.0        1
# 3757.0        1
# 3756.0        1
# 3158.0        1
# 3438.0        1
# 3340.0        1
# 3115.0        1
# 3431.0        1

# %%
## apply pie chart to visualize the house type without value in car column. 
car_grouped = car_na.groupby('Type').size()
car_grouped.plot(kind='pie', subplots = True, figsize=(8,8))
plt.title('Pie chart of the house type without value in column Car')
plt.ylabel('')
plt.show()

# %% [markdown]
# #### We can conclude that the missing values in car include property types of both unit and house. Based on the domain knowledge, the house has at least the street parking space, we can fill them as 1 car space. As for unit, no reference can be made without supporting data, we can use 0 to fill here as it is a very low portion in this data, also because the car space does not alter the pricing of unit much based on the domain knowledge.

# %% [markdown]
# #### Filling the missing value in column 'Car'

# %%
melb_house['Car'].fillna('unknown', inplace=True)

# %%
melb_house.loc[melb_house[['Type']] == 'h' & melb_house[['Car']] == None, 'Car']=1
melb_house.loc[melb_house[['Type']] == 'u' & melb_house[['Car']] == None, 'Car']=0
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/ops/array_ops.py:301, in na_logical_op(x, y, op)
#     292 try:
#     293     # For exposition, write:
#     294     #  yarr = isinstance(y, np.ndarray)
#    (...)
#     299     # Then Cases where this goes through without raising include:
#     300     #  (xint or xbool) and (yint or bool)
# --> 301     result = op(x, y)
#     302 except TypeError:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/roperator.py:52, in rand_(left, right)
#      51 def rand_(left, right):
# ---> 52     return operator.and_(right, left)
#
# TypeError: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/ops/array_ops.py:315, in na_logical_op(x, y, op)
#     314 try:
# --> 315     result = libops.scalar_binop(x, y, op)
#     316 except (
#     317     TypeError,
#     318     ValueError,
#    (...)
#     321     NotImplementedError,
#     322 ) as err:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/ops.pyx:180, in pandas._libs.ops.scalar_binop()
#
# ValueError: Buffer has wrong number of dimensions (expected 1, got 2)
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 melb_house.loc[melb_house[['Type']] == 'h' & melb_house[['Car']] == None, 'Car']=1
#       2 melb_house.loc[melb_house[['Type']] == 'u' & melb_house[['Car']] == None, 'Car']=0
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/ops/common.py:70, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      66             return NotImplemented
#      68 other = item_from_zerodim(other)
# ---> 70 return method(self, other)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arraylike.py:74, in OpsMixin.__rand__(self, other)
#      72 @unpack_zerodim_and_defer("__rand__")
#      73 def __rand__(self, other):
# ---> 74     return self._logical_method(other, roperator.rand_)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:6952, in DataFrame._arith_method(self, other, op)
#    6948 other = ops.maybe_prepare_scalar_for_op(other, (self.shape[axis],))
#    6950 self, other = ops.align_method_FRAME(self, other, axis, flex=True, level=None)
# -> 6952 new_data = self._dispatch_frame_op(other, op, axis=axis)
#    6953 return self._construct_result(new_data)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:6979, in DataFrame._dispatch_frame_op(self, right, func, axis)
#    6976 if not is_list_like(right):
#    6977     # i.e. scalar, faster than checking np.ndim(right) == 0
#    6978     with np.errstate(all="ignore"):
# -> 6979         bm = self._mgr.apply(array_op, right=right)
#    6980     return self._constructor(bm)
#    6982 elif isinstance(right, DataFrame):
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py:302, in BaseBlockManager.apply(self, f, align_keys, ignore_failures, **kwargs)
#     300 try:
#     301     if callable(f):
# --> 302         applied = b.apply(f, **kwargs)
#     303     else:
#     304         applied = getattr(b, f)(**kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/blocks.py:402, in Block.apply(self, func, **kwargs)
#     396 @final
#     397 def apply(self, func, **kwargs) -> list[Block]:
#     398     """
#     399     apply the function to my values; return a block if we are not
#     400     one
#     401     """
# --> 402     result = func(self.values, **kwargs)
#     404     return self._split_op_result(result)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/ops/array_ops.py:391, in logical_op(left, right, op)
#     387 # For int vs int `^`, `|`, `&` are bitwise operators and return
#     388 #   integer dtypes.  Otherwise these are boolean ops
#     389 filler = fill_int if is_self_int_dtype and is_other_int_dtype else fill_bool
# --> 391 res_values = na_logical_op(lvalues, rvalues, op)
#     392 # error: Cannot call function of unknown type
#     393 res_values = filler(res_values)  # type: ignore[operator]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/ops/array_ops.py:324, in na_logical_op(x, y, op)
#     316         except (
#     317             TypeError,
#     318             ValueError,
#    (...)
#     321             NotImplementedError,
#     322         ) as err:
#     323             typ = type(y).__name__
# --> 324             raise TypeError(
#     325                 f"Cannot perform '{op.__name__}' with a dtyped [{x.dtype}] array "
#     326                 f"and scalar of type [{typ}]"
#     327             ) from err
#     329 return result.reshape(x.shape)
#
# TypeError: Cannot perform 'rand_' with a dtyped [float64] array and scalar of type [bool]

# %%
sns.set_theme(style="darkgrid")
sns.countplot(x=melb_house['Method'])
# Out:
# <AxesSubplot:xlabel='Method', ylabel='count'>

# %% [markdown]
# ## _Section 2: Features analyzing_

# %% [markdown]
# ##### Regionname

# %%
melb_house['Regionname'].unique()
# Out:
# array(['Northern Metropolitan', 'Western Metropolitan',
#        'Southern Metropolitan', 'Eastern Metropolitan',
#        'South-Eastern Metropolitan', 'Eastern Victoria',
#        'Northern Victoria', 'Western Victoria'], dtype=object)

# %% [markdown]
# ##### Suburb: How is the property distributed based on suburb?

# %%
sub_count = melb_house['Suburb'].reset_index()
df = sub_count.groupby('Suburb').agg('count').reset_index()
df2 = df[df['index']>50]
df2.columns
# Out:
# Index(['Suburb', 'index'], dtype='object')

# %%
squarify.plot(df2['index'],label=df2['Suburb'], pad=True)

plt.axis('off')
plt.show()

# %% [markdown]
# ##### Landsize

# %%
melb_house['Landsize']

# %% [markdown]
# ##### Buildingarea

# %% [markdown]
# ##### Bedrooms

# %% [markdown]
# ##### Bathrooms

# %% [markdown]
# ##### House Type: How many housing types we have and how are they distributed?

# %%
sns.countplot(x=melb_house['Type'])
# Out:
# <AxesSubplot:xlabel='Type', ylabel='count'>

# %%
melb_house.groupby('Type').agg('count')
# Out:
#       Suburb  Address  Rooms  Price  Method  SellerG  Date  Distance  \
# Type
# h       9449     9449   9449   9449    9449     9449  9449      9449
# t       1114     1114   1114   1114    1114     1114  1114      1114
# u       3017     3017   3017   3017    3017     3017  3017      3017
#
#       Postcode  Bedroom2  Bathroom   Car  Landsize  BuildingArea  YearBuilt  \
# Type
# h         9449      9449      9449  9449      9449          4860       5408
# t         1114      1114      1114  1114      1114           686        762
# u         3017      3017      3017  3017      3017          1584       2035
#
#       CouncilArea  Lattitude  Longtitude  Regionname  Propertycount
# Type
# h            8204       9449        9449        9449           9449
# t            1045       1114        1114        1114           1114
# u            2962       3017        3017        3017           3017

# %% [markdown]
# ##### Price: How housing price distributed according to house type?

# %% [markdown]
# ## _Section 3: Model building_

# %% [markdown]
# ## _Model Interpretation_

# %% [markdown]
# ## _Melbourne housing market trend(16-17)_
