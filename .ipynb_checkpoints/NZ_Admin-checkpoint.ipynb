# %% [markdown]
# ### Import Library

# %%
import pandas as pd

# %%
nz_admin = pd.read_csv('file/NZ_Admin_JOBS.csv', header=None)
nz_admin.head()
# Out:
#                                       0  \
# 0                                   字段1
# 1                         Administrator
# 2                          Receptionist
# 3          Prosecutions Support Officer
# 4  Early Childhood Centre Administrator
#
#                                                    1  \
# 0                                           字段1_link
# 1  https://www.seek.co.nz/job/50582301?type=promo...
# 2  https://www.seek.co.nz/job/50620889?type=promo...
# 3  https://www.seek.co.nz/job/50622169?type=stand...
# 4  https://www.seek.co.nz/job/50639620?type=stand...
#
#                                           2  \
# 0                                       字段2
# 1                                       NaN
# 2                      Avenues Orthodontics
# 3                        New Zealand Police
# 4  Kew Pacific Island Early Learning Centre
#
#                                                    3  \
# 0                                                字段3
# 1  location: Bay of PlentyBay of Plentyarea: Taur...
# 2  location: Bay of PlentyBay of Plentyarea: Taur...
# 3                         location: AucklandAuckland
# 4  location: SouthlandSouthlandarea: Invercargill...
#
#                                 4  \
# 0                             字段4
# 1  Featured,at,Private Advertiser
# 2                     Featured,at
# 3                       4d ago,at
# 4                       1h ago,at
#
#                                                    5
# 0                                                字段5
# 1  classification: Administration & Office Suppor...
# 2  classification: Administration & Office Suppor...
# 3  classification: Administration & Office Suppor...
# 4  classification: Administration & Office Suppor...

# %%
nzAdmin = nz_admin.drop([0]).reset_index()
nzAdmin.head()
# Out:
#    index                                     0  \
# 0      1                         Administrator
# 1      2                          Receptionist
# 2      3          Prosecutions Support Officer
# 3      4  Early Childhood Centre Administrator
# 4      5        Business Support Administrator
#
#                                                    1  \
# 0  https://www.seek.co.nz/job/50582301?type=promo...
# 1  https://www.seek.co.nz/job/50620889?type=promo...
# 2  https://www.seek.co.nz/job/50622169?type=stand...
# 3  https://www.seek.co.nz/job/50639620?type=stand...
# 4  https://www.seek.co.nz/job/50622432?type=stand...
#
#                                           2  \
# 0                                       NaN
# 1                      Avenues Orthodontics
# 2                        New Zealand Police
# 3  Kew Pacific Island Early Learning Centre
# 4                                       NaN
#
#                                                    3  \
# 0  location: Bay of PlentyBay of Plentyarea: Taur...
# 1  location: Bay of PlentyBay of Plentyarea: Taur...
# 2                         location: AucklandAuckland
# 3  location: SouthlandSouthlandarea: Invercargill...
# 4  location: CanterburyCanterburyarea: Christchur...
#
#                                 4  \
# 0  Featured,at,Private Advertiser
# 1                     Featured,at
# 2                       4d ago,at
# 3                       1h ago,at
# 4    4d ago,at,Private Advertiser
#
#                                                    5
# 0  classification: Administration & Office Suppor...
# 1  classification: Administration & Office Suppor...
# 2  classification: Administration & Office Suppor...
# 3  classification: Administration & Office Suppor...
# 4  classification: Administration & Office Suppor...

# %%
nzAdmin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2708 entries, 0 to 2707
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   index   2708 non-null   int64
#  1   0       2708 non-null   object
#  2   1       2708 non-null   object
#  3   2       2686 non-null   object
#  4   3       2708 non-null   object
#  5   4       2708 non-null   object
#  6   5       2708 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 148.2+ KB

# %%
nzAdmin.isnull().sum()
# Out:
# index     0
# 0         0
# 1         0
# 2        22
# 3         0
# 4         0
# 5         0
# dtype: int64

# %%
nzAdmin[3].unique()
# Out:
# array(['location: Bay of PlentyBay of Plentyarea: TaurangaTauranga',
#        'location: AucklandAuckland',
#        'location: SouthlandSouthlandarea: InvercargillInvercargill',
#        'location: CanterburyCanterburyarea: ChristchurchChristchurch',
#        'location: NorthlandNorthlandarea: WhangareiWhangarei',
#        'location: WellingtonWellingtonarea: Wellington CentralWellington Central',
#        'location: Bay of PlentyBay of Plentyarea: RotoruaRotorua',
#        'location: CanterburyCanterbury',
#        'location: West CoastWest Coastarea: Rest of West CoastRest of West Coast',
#        'location: TasmanTasmanarea: NelsonNelson',
#        'location: AucklandAucklandarea: Manukau & East AucklandManukau & East Auckland,$20 per hour',
#        'location: CanterburyCanterburyarea: Rest of CanterburyRest of Canterbury',
#        'location: CanterburyCanterburyarea: Timaru & South CanterburyTimaru & South Canterbury',
#        'location: AucklandAucklandarea: Auckland CentralAuckland Central',
#        'location: AucklandAucklandarea: Auckland CentralAuckland Central,$20 - $24.99 per hour',
#        'location: ManawatuManawatuarea: Rest of ManawatuRest of Manawatu',
#        'location: AucklandAucklandarea: Papakura & FranklinPapakura & Franklin',
#        'location: AucklandAucklandarea: Rodney & North ShoreRodney & North Shore,$19 to $22 per hour',
#        'location: WaikatoWaikatoarea: Rest of WaikatoRest of Waikato',
#        'location: AucklandAucklandarea: Manukau & East AucklandManukau & East Auckland,$20 - $24.99 per hour',
#        'location: Hawkes BayHawkes Bayarea: HastingsHastings',
#        'location: OtagoOtagoarea: Queenstown & WanakaQueenstown & Wanaka',
#        'location: OtagoOtagoarea: Rest of OtagoRest of Otago',
#        'location: WaikatoWaikatoarea: HamiltonHamilton',
#        'location: WaikatoWaikatoarea: Rest of WaikatoRest of Waikato,$20 - $24.99 per hour',
#        'location: WellingtonWellingtonarea: Hutt ValleyHutt Valley',
#        'location: TaranakiTaranakiarea: New PlymouthNew Plymouth',
#        'location: ManawatuManawatuarea: Palmerston NorthPalmerston North,$40,000 - $49,999',
#        'location: AucklandAucklandarea: Waitakere & West AucklandWaitakere & West Auckland',
#        'location: NorthlandNorthlandarea: WhangareiWhangarei,$25 per hour',
#        'location: AucklandAucklandarea: Manukau & East AucklandManukau & East Auckland',
#        'location: TaranakiTaranakiarea: Rest of TaranakiRest of Taranaki',
#        'location: WaikatoWaikatoarea: HamiltonHamilton,Includes life and health insurance',
#        'location: Bay of PlentyBay of Plentyarea: TaurangaTauranga,$60 000 - $70 000 per annum',
#        'location: AucklandAucklandarea: Manukau & East AucklandManukau & East Auckland,$20.00 per hour',
#        'location: AucklandAucklandarea: Auckland CentralAuckland Central,Includes life and health insurance',
#        'location: AucklandAucklandarea: Rodney & North ShoreRodney & North Shore',
#        'location: OtagoOtagoarea: DunedinDunedin',
#        'location: Bay of PlentyBay of Plentyarea: Rest of Bay of PlentyRest of Bay of Plenty,$20 - $24.99 per hour',
#        'location: MarlboroughMarlborougharea: BlenheimBlenheim',
#        'location: CanterburyCanterburyarea: ChristchurchChristchurch,$55,000 - $69,999',
#        'location: WellingtonWellingtonarea: Wellington CentralWellington Central,$20.00 per hour.',
#        'location: AucklandAucklandarea: Papakura & FranklinPapakura & Franklin,$20 - $24.99 per hour',
#        'location: AucklandAucklandarea: Manukau & East AucklandManukau & East Auckland,$21 per hour',
#        'location: WaikatoWaikatoarea: HamiltonHamilton,$55,000 - $64,999',
#        'location: WaikatoWaikatoarea: Thames & CoromandelThames & Coromandel',
#        'location: AucklandAucklandarea: Auckland CentralAuckland Central,$50,000 - $55,000 plus benefits',
#        'location: ManawatuManawatuarea: Palmerston NorthPalmerston North,incl Life & Health Insurance',
#        'location: AucklandAucklandarea: Auckland CentralAuckland Central,$45,000 - $49,999',
#        'location: ManawatuManawatuarea: Palmerston NorthPalmerston North',
#        'location: WellingtonWellingtonarea: Wellington CentralWellington Central,$55,000 - $60,000 per annum pro rata',
#        'location: AucklandAucklandarea: Rodney & North ShoreRodney & North Shore,Includes life and health insurance',
#        'location: TasmanTasmanarea: Rest of TasmanRest of Tasman',
#        'location: WellingtonWellingtonarea: Wellington CentralWellington Central,$20 - $24.99 per hour',
#        'location: AucklandAucklandarea: Manukau & East AucklandManukau & East Auckland,$48,835 - $63,221',
#        'location: AucklandAucklandarea: Waitakere & West AucklandWaitakere & West Auckland,$20 - $29.99 per hour',
#        'location: WellingtonWellingtonarea: Hutt ValleyHutt Valley,$24-$28',
#        'location: ManawatuManawatuarea: Palmerston NorthPalmerston North,Up to $27ph',
#        'location: Hawkes BayHawkes Bayarea: NapierNapier',
#        'location: WellingtonWellingtonarea: Wellington CentralWellington Central,$20 - $29.99 per hour',
#        'location: OtagoOtagoarea: DunedinDunedin,$20 - $29.99 per hour',
#        'location: MarlboroughMarlborough',
#        'location: WellingtonWellington',
#        'location: Hawkes BayHawkes Bayarea: Rest of Hawkes BayRest of Hawkes Bay',
#        'location: AucklandAucklandarea: Waitakere & West AucklandWaitakere & West Auckland,8% holiday pay',
#        'location: GisborneGisbornearea: GisborneGisborne',
#        'location: AucklandAucklandarea: Waitakere & West AucklandWaitakere & West Auckland,$55,000 - $64,999',
#        'location: WellingtonWellingtonarea: Wellington CentralWellington Central,$40,000 - $49,999',
#        'location: NorthlandNorthlandarea: Rest of NorthlandRest of Northland',
#        'location: AucklandAucklandarea: Auckland CentralAuckland Central,$45,000 - $59,999',
#        'location: AucklandAucklandarea: Manukau & East AucklandManukau & East Auckland,NZD25 - NZD28 per hour',
#        'location: WellingtonWellingtonarea: Porirua & Kapiti CoastPorirua & Kapiti Coast',
#        'location: AucklandAucklandarea: Rodney & North ShoreRodney & North Shore,$45,000 - $49,999',
#        'location: AucklandAucklandarea: Auckland CentralAuckland Central,Competitive Salary',
#        'location: WellingtonWellingtonarea: Rest of Wellington RegionRest of Wellington Region',
#        'location: Hawkes BayHawkes Bayarea: HastingsHastings,$22 per hour',
#        'location: AucklandAucklandarea: Auckland CentralAuckland Central,NZD75000 per annum',
#        'location: AucklandAucklandarea: Rodney & North ShoreRodney & North Shore,$20 - $24.99 per hour',
#        'location: WellingtonWellington,$75k - $85k p.a.',
#        'location: AucklandAucklandarea: Auckland CentralAuckland Central,$24 - $25 + 8% holiday pay!',
#        'location: ManawatuManawatuarea: WanganuiWanganui',
#        'location: AucklandAucklandarea: Rodney & North ShoreRodney & North Shore,$40,000 - $49,999',
#        'location: WellingtonWellingtonarea: Wellington CentralWellington Central,$50,000 per annum.',
#        'location: AucklandAucklandarea: Manukau & East AucklandManukau & East Auckland,bonus plus medical insurance',
#        'location: AucklandAucklandarea: Manukau & East AucklandManukau & East Auckland,$20 - $25 per hour',
#        'location: ManawatuManawatu',
#        'location: TaranakiTaranakiarea: Rest of TaranakiRest of Taranaki,$20 - $24.99 per hour',
#        'location: WellingtonWellingtonarea: Wellington CentralWellington Central,Good salary',
#        'location: AucklandAucklandarea: Auckland CentralAuckland Central,$30 - $38 p.h. + 8% Holiday Pay',
#        'location: MarlboroughMarlborougharea: BlenheimBlenheim,$45-$55,000',
#        'location: AucklandAucklandarea: Waitakere & West AucklandWaitakere & West Auckland,$50,000 - $54,999',
#        'location: AucklandAucklandarea: Auckland CentralAuckland Central,Up to $23 p.h. + + 8% Holiday Pay',
#        'location: WellingtonWellington,Up to $22.00 p.h.',
#        'location: WellingtonWellingtonarea: Wellington CentralWellington Central,NZD69,726-94,127p.a.+Retirement contributions',
#        'location: AucklandAucklandarea: Rodney & North ShoreRodney & North Shore,$60k-$70k depending on experience!',
#        'location: AucklandAucklandarea: Auckland CentralAuckland Central,$22.00 - $23.00 phr',
#        'location: AucklandAucklandarea: Waitakere & West AucklandWaitakere & West Auckland,$40,000 - $49,999',
#        'location: AucklandAucklandarea: Manukau & East AucklandManukau & East Auckland,$27 - $33 p.h. + 8% holiday pay',
#        'location: AucklandAucklandarea: Auckland CentralAuckland Central,$60K - $80K experience dependent',
#        'location: AucklandAucklandarea: Waitakere & West AucklandWaitakere & West Auckland,$60 - $65k + Career Progression to QS / leadership',
#        'location: Bay of PlentyBay of Plentyarea: Rest of Bay of PlentyRest of Bay of Plenty',
#        'location: AucklandAucklandarea: Rodney & North ShoreRodney & North Shore,$35 - $39.99 per hour',
#        'location: OtagoOtagoarea: Queenstown & WanakaQueenstown & Wanaka,$55,000 - $64,999',
#        'location: WaikatoWaikatoarea: TaupoTaupo',
#        'location: AucklandAucklandarea: Waitakere & West AucklandWaitakere & West Auckland,$20 - $24.99 per hour dependent on experience.',
#        'location: AucklandAucklandarea: Auckland CentralAuckland Central,Up to $27 p.h. + 8% Holiday Pay',
#        'location: Bay of PlentyBay of Plenty',
#        'location: CanterburyCanterburyarea: ChristchurchChristchurch,NZD19 - NZD23 per hour',
#        'location: AucklandAucklandarea: Auckland CentralAuckland Central,$60,000 pa',
#        'location: AucklandAucklandarea: Manukau & East AucklandManukau & East Auckland,$21 - $25 p.h. + 8% Holiday Pay',
#        'location: WellingtonWellingtonarea: Wellington CentralWellington Central,$60,000 - $69,999',
#        'location: CanterburyCanterburyarea: ChristchurchChristchurch,$21-$23 per hour',
#        'location: AucklandAucklandarea: Papakura & FranklinPapakura & Franklin,$50,000 - $59,999',
#        'location: AucklandAucklandarea: Auckland CentralAuckland Central,$40 - $45 per hour',
#        'location: OtagoOtagoarea: Rest of OtagoRest of Otago,$18.50 - $23.50 per hour',
#        'location: WellingtonWellingtonarea: Porirua & Kapiti CoastPorirua & Kapiti Coast,$25.5',
#        'location: AucklandAucklandarea: Auckland CentralAuckland Central,Up to $35 p.h. + 8% Holiday Pay',
#        'location: AucklandAuckland,$21 - $22 p.h. + 8% Holiday Pay',
#        'location: WellingtonWellingtonarea: Wellington CentralWellington Central,NZD25 - NZD30 per hour',
#        'location: AucklandAucklandarea: Manukau & East AucklandManukau & East Auckland,$25 - $29.99 per hour',
#        'location: SouthlandSouthlandarea: InvercargillInvercargill,Competitive',
#        'location: AucklandAucklandarea: Auckland CentralAuckland Central,$50,000 - $69,999',
#        'location: CanterburyCanterburyarea: ChristchurchChristchurch,Attractive salary neg.',
#        'location: WaikatoWaikatoarea: Rest of WaikatoRest of Waikato,$50,000 - $59,999',
#        'location: OtagoOtagoarea: DunedinDunedin,$25 - $29.99 per hour',
#        'location: OtagoOtagoarea: DunedinDunedin,$50,000 - $64,999',
#        'location: AucklandAucklandarea: Auckland CentralAuckland Central,$20 - $40 per hour',
#        'location: AucklandAucklandarea: Rodney & North ShoreRodney & North Shore,$48,000 - $55,000',
#        'location: WellingtonWellington,$50k - $65k p.a. + plus kiwisaver',
#        'location: AucklandAuckland,$70-$80k+Super',
#        'location: WellingtonWellington,$20 - $30 per hour',
#        'location: AucklandAucklandarea: Auckland CentralAuckland Central,$45,000 - $54,999',
#        'location: WaikatoWaikatoarea: HamiltonHamilton,Competitive hourly rate, experience dependent',
#        'location: AucklandAucklandarea: Rodney & North ShoreRodney & North Shore,$55,000 - $65,000 depending on relevant experience',
#        'location: AucklandAucklandarea: Rodney & North ShoreRodney & North Shore,Competitive salary + phone + parking!',
#        'location: WellingtonWellingtonarea: Wellington CentralWellington Central,$70-75k per annum',
#        'location: AucklandAucklandarea: Manukau & East AucklandManukau & East Auckland,Competitive salary',
#        'location: AucklandAucklandarea: Auckland CentralAuckland Central,$45,000 - $55,000 depending on experience',
#        'location: AucklandAucklandarea: Auckland CentralAuckland Central,$24 - $28 p.h.  + 8% Holiday Pay',
#        'location: AucklandAucklandarea: Auckland CentralAuckland Central,$35 - $40 p.h. + + 8% Holiday Pay',
#        'location: AucklandAucklandarea: Auckland CentralAuckland Central,+ Car park, close to public transport',
#        'location: AucklandAucklandarea: Papakura & FranklinPapakura & Franklin,Circa 50k',
#        'location: WellingtonWellingtonarea: Wellington CentralWellington Central,Send us your CV today!',
#        'location: WaikatoWaikatoarea: HamiltonHamilton,Competitive hourly rates $$',
#        'location: AucklandAucklandarea: Auckland CentralAuckland Central,Competitive hourly rate depending on experience',
#        'location: WellingtonWellington,Attractive remuneration',
#        'location: WellingtonWellingtonarea: Wellington CentralWellington Central,Competitive hourly rate'],
#       dtype=object)

# %%
## filter other information (not location or area) out
nzAdmin[3] = nzAdmin[3].str.split(',', n=1, expand=True)[0]
nzAdmin[3]
# Out:
# 0       location: Bay of PlentyBay of Plentyarea: Taur...
# 1       location: Bay of PlentyBay of Plentyarea: Taur...
# 2                              location: AucklandAuckland
# 3       location: SouthlandSouthlandarea: Invercargill...
# 4       location: CanterburyCanterburyarea: Christchur...
#                               ...
# 2703    location: AucklandAucklandarea: Auckland Centr...
# 2704    location: WellingtonWellingtonarea: Wellington...
# 2705       location: WaikatoWaikatoarea: HamiltonHamilton
# 2706       location: WaikatoWaikatoarea: HamiltonHamilton
# 2707                       location: WellingtonWellington
# Name: 3, Length: 2708, dtype: object

# %%
## split location and area and store them in new columns 
nzAdmin[['location', 'area']] = nzAdmin[3].str.split('area:', n=1, expand=True)
nzAdmin.head()
# Out:
#    index                                     0  \
# 0      1                         Administrator
# 1      2                          Receptionist
# 2      3          Prosecutions Support Officer
# 3      4  Early Childhood Centre Administrator
# 4      5        Business Support Administrator
#
#                                                    1  \
# 0  https://www.seek.co.nz/job/50582301?type=promo...
# 1  https://www.seek.co.nz/job/50620889?type=promo...
# 2  https://www.seek.co.nz/job/50622169?type=stand...
# 3  https://www.seek.co.nz/job/50639620?type=stand...
# 4  https://www.seek.co.nz/job/50622432?type=stand...
#
#                                           2  \
# 0                                       NaN
# 1                      Avenues Orthodontics
# 2                        New Zealand Police
# 3  Kew Pacific Island Early Learning Centre
# 4                                       NaN
#
#                                                    3  \
# 0  location: Bay of PlentyBay of Plentyarea: Taur...
# 1  location: Bay of PlentyBay of Plentyarea: Taur...
# 2                         location: AucklandAuckland
# 3  location: SouthlandSouthlandarea: Invercargill...
# 4  location: CanterburyCanterburyarea: Christchur...
#
#                                 4  \
# 0  Featured,at,Private Advertiser
# 1                     Featured,at
# 2                       4d ago,at
# 3                       1h ago,at
# 4    4d ago,at,Private Advertiser
#
#                                                    5  \
# 0  classification: Administration & Office Suppor...
# 1  classification: Administration & Office Suppor...
# 2  classification: Administration & Office Suppor...
# 3  classification: Administration & Office Suppor...
# 4  classification: Administration & Office Suppor...
#
#                                location                       area
# 0  location: Bay of PlentyBay of Plenty           TaurangaTauranga
# 1  location: Bay of PlentyBay of Plenty           TaurangaTauranga
# 2            location: AucklandAuckland                       None
# 3          location: SouthlandSouthland   InvercargillInvercargill
# 4        location: CanterburyCanterbury   ChristchurchChristchurch

# %%
nzAdmin['location'].isna().sum()
# Out:
# 0

# %%
nzAdmin['area'].isna().sum()
# Out:
# 541

# %%
## use lambda function to filter out extra words
nzAdmin['location'] = nzAdmin['location'].apply(lambda x:x[9:])
nzAdmin['location']
# Out:
# 0        Bay of PlentyBay of Plenty
# 1        Bay of PlentyBay of Plenty
# 2                  AucklandAuckland
# 3                SouthlandSouthland
# 4              CanterburyCanterbury
#                    ...
# 2703               AucklandAuckland
# 2704           WellingtonWellington
# 2705                 WaikatoWaikato
# 2706                 WaikatoWaikato
# 2707           WellingtonWellington
# Name: location, Length: 2708, dtype: object

# %%
##handle duplication issue 
def handle_duplication(x):
    trim = x.strip()
    index = (trim+trim).find(trim,1)
    if index != -1:
        return trim[:index]
    else:
        return trim

# %%
nzAdmin['location'] = nzAdmin['location'].apply(handle_duplication)

# %%
nzAdmin['location']
# Out:
# 0       Bay of Plenty
# 1       Bay of Plenty
# 2            Auckland
# 3           Southland
# 4          Canterbury
#             ...
# 2703         Auckland
# 2704       Wellington
# 2705          Waikato
# 2706          Waikato
# 2707       Wellington
# Name: location, Length: 2708, dtype: object

# %%
## drop column 3 as the information is extracted and saved in location and area
nzAdmin.drop(columns = 3, axis=1, inplace=True)

# %%
nzAdmin.head()
# Out:
#    index                                     0  \
# 0      1                         Administrator
# 1      2                          Receptionist
# 2      3          Prosecutions Support Officer
# 3      4  Early Childhood Centre Administrator
# 4      5        Business Support Administrator
#
#                                                    1  \
# 0  https://www.seek.co.nz/job/50582301?type=promo...
# 1  https://www.seek.co.nz/job/50620889?type=promo...
# 2  https://www.seek.co.nz/job/50622169?type=stand...
# 3  https://www.seek.co.nz/job/50639620?type=stand...
# 4  https://www.seek.co.nz/job/50622432?type=stand...
#
#                                           2                               4  \
# 0                                       NaN  Featured,at,Private Advertiser
# 1                      Avenues Orthodontics                     Featured,at
# 2                        New Zealand Police                       4d ago,at
# 3  Kew Pacific Island Early Learning Centre                       1h ago,at
# 4                                       NaN    4d ago,at,Private Advertiser
#
#                                                    5       location  \
# 0  classification: Administration & Office Suppor...  Bay of Plenty
# 1  classification: Administration & Office Suppor...  Bay of Plenty
# 2  classification: Administration & Office Suppor...       Auckland
# 3  classification: Administration & Office Suppor...      Southland
# 4  classification: Administration & Office Suppor...     Canterbury
#
#                         area
# 0           TaurangaTauranga
# 1           TaurangaTauranga
# 2                       None
# 3   InvercargillInvercargill
# 4   ChristchurchChristchurch

# %%
## fill blank cell in area and perform the function to handle duplication
nzAdmin['area'].fillna('unknown', inplace = True)

# %%
nzAdmin['area'] = nzAdmin['area'].apply(handle_duplication)

# %%
nzAdmin.head()
# Out:
#    index                                     0  \
# 0      1                         Administrator
# 1      2                          Receptionist
# 2      3          Prosecutions Support Officer
# 3      4  Early Childhood Centre Administrator
# 4      5        Business Support Administrator
#
#                                                    1  \
# 0  https://www.seek.co.nz/job/50582301?type=promo...
# 1  https://www.seek.co.nz/job/50620889?type=promo...
# 2  https://www.seek.co.nz/job/50622169?type=stand...
# 3  https://www.seek.co.nz/job/50639620?type=stand...
# 4  https://www.seek.co.nz/job/50622432?type=stand...
#
#                                           2                               4  \
# 0                                       NaN  Featured,at,Private Advertiser
# 1                      Avenues Orthodontics                     Featured,at
# 2                        New Zealand Police                       4d ago,at
# 3  Kew Pacific Island Early Learning Centre                       1h ago,at
# 4                                       NaN    4d ago,at,Private Advertiser
#
#                                                    5       location  \
# 0  classification: Administration & Office Suppor...  Bay of Plenty
# 1  classification: Administration & Office Suppor...  Bay of Plenty
# 2  classification: Administration & Office Suppor...       Auckland
# 3  classification: Administration & Office Suppor...      Southland
# 4  classification: Administration & Office Suppor...     Canterbury
#
#            area
# 0      Tauranga
# 1      Tauranga
# 2       unknown
# 3  Invercargill
# 4  Christchurch

# %%
## Extract information from column 5 and saved to classification and subclassification
nzAdmin[['subclassification', 'classification']]=nzAdmin[5].str.split('subClassification:', expand = True)

# %%
nzAdmin.head()
# Out:
#    index                                     0  \
# 0      1                         Administrator
# 1      2                          Receptionist
# 2      3          Prosecutions Support Officer
# 3      4  Early Childhood Centre Administrator
# 4      5        Business Support Administrator
#
#                                                    1  \
# 0  https://www.seek.co.nz/job/50582301?type=promo...
# 1  https://www.seek.co.nz/job/50620889?type=promo...
# 2  https://www.seek.co.nz/job/50622169?type=stand...
# 3  https://www.seek.co.nz/job/50639620?type=stand...
# 4  https://www.seek.co.nz/job/50622432?type=stand...
#
#                                           2                               4  \
# 0                                       NaN  Featured,at,Private Advertiser
# 1                      Avenues Orthodontics                     Featured,at
# 2                        New Zealand Police                       4d ago,at
# 3  Kew Pacific Island Early Learning Centre                       1h ago,at
# 4                                       NaN    4d ago,at,Private Advertiser
#
#                                                    5       location  \
# 0  classification: Administration & Office Suppor...  Bay of Plenty
# 1  classification: Administration & Office Suppor...  Bay of Plenty
# 2  classification: Administration & Office Suppor...       Auckland
# 3  classification: Administration & Office Suppor...      Southland
# 4  classification: Administration & Office Suppor...     Canterbury
#
#            area                                  subclassification  \
# 0      Tauranga  classification: Administration & Office Suppor...
# 1      Tauranga  classification: Administration & Office Suppor...
# 2       unknown  classification: Administration & Office Suppor...
# 3  Invercargill  classification: Administration & Office Suppor...
# 4  Christchurch  classification: Administration & Office Suppor...
#
#                                       classification
# 0                 Office ManagementOffice Management
# 1                         ReceptionistsReceptionists
# 2                                         OtherOther
# 3   Administrative AssistantsAdministrative Assis...
# 4   Client & Sales AdministrationClient & Sales A...

# %%
nzAdmin['classification'].isna().sum()
# Out:
# 603

# %%
nzAdmin['subclassification'].isna().sum()
# Out:
# 0

# %%
nzAdmin['classification'].fillna('unknown', inplace= True)

# %%
## handle duplication situation in classification column
nzAdmin['classification']=nzAdmin['classification'].apply(handle_duplication)

# %%
nzAdmin['classification'].head()
# Out:
# 0                Office Management
# 1                    Receptionists
# 2                            Other
# 3        Administrative Assistants
# 4    Client & Sales Administration
# Name: classification, dtype: object

# %%
def extract_salary(x):
    if 'classification:' in x:
        return 'unknown'
    else:
        return x

# %%
def clean_classification(x):
    if 'classification' in x:
        return x[15:]
    else:
        return 'unknown'

# %%
## extract salary
nzAdmin['salary'] = nzAdmin['subclassification'].apply(extract_salary)
## clean column 4
nzAdmin[['posted time', 'featured at']] = nzAdmin[4].str.split(',', expand = True)[[0,2]]
nzAdmin.head()
# Out:
#    index                                     0  \
# 0      1                         Administrator
# 1      2                          Receptionist
# 2      3          Prosecutions Support Officer
# 3      4  Early Childhood Centre Administrator
# 4      5        Business Support Administrator
#
#                                                    1  \
# 0  https://www.seek.co.nz/job/50582301?type=promo...
# 1  https://www.seek.co.nz/job/50620889?type=promo...
# 2  https://www.seek.co.nz/job/50622169?type=stand...
# 3  https://www.seek.co.nz/job/50639620?type=stand...
# 4  https://www.seek.co.nz/job/50622432?type=stand...
#
#                                           2                               4  \
# 0                                       NaN  Featured,at,Private Advertiser
# 1                      Avenues Orthodontics                     Featured,at
# 2                        New Zealand Police                       4d ago,at
# 3  Kew Pacific Island Early Learning Centre                       1h ago,at
# 4                                       NaN    4d ago,at,Private Advertiser
#
#                                                    5       location  \
# 0  classification: Administration & Office Suppor...  Bay of Plenty
# 1  classification: Administration & Office Suppor...  Bay of Plenty
# 2  classification: Administration & Office Suppor...       Auckland
# 3  classification: Administration & Office Suppor...      Southland
# 4  classification: Administration & Office Suppor...     Canterbury
#
#            area                                  subclassification  \
# 0      Tauranga  classification: Administration & Office Suppor...
# 1      Tauranga  classification: Administration & Office Suppor...
# 2       unknown  classification: Administration & Office Suppor...
# 3  Invercargill  classification: Administration & Office Suppor...
# 4  Christchurch  classification: Administration & Office Suppor...
#
#                   classification   salary posted time         featured at
# 0              Office Management  unknown    Featured  Private Advertiser
# 1                  Receptionists  unknown    Featured                None
# 2                          Other  unknown      4d ago                None
# 3      Administrative Assistants  unknown      1h ago                None
# 4  Client & Sales Administration  unknown      4d ago  Private Advertiser

# %%
nzAdmin['subclassification'] = nzAdmin['subclassification'].apply(clean_classification)
nzAdmin.head()
# Out:
#    index                                     0  \
# 0      1                         Administrator
# 1      2                          Receptionist
# 2      3          Prosecutions Support Officer
# 3      4  Early Childhood Centre Administrator
# 4      5        Business Support Administrator
#
#                                                    1  \
# 0  https://www.seek.co.nz/job/50582301?type=promo...
# 1  https://www.seek.co.nz/job/50620889?type=promo...
# 2  https://www.seek.co.nz/job/50622169?type=stand...
# 3  https://www.seek.co.nz/job/50639620?type=stand...
# 4  https://www.seek.co.nz/job/50622432?type=stand...
#
#                                           2                               4  \
# 0                                       NaN  Featured,at,Private Advertiser
# 1                      Avenues Orthodontics                     Featured,at
# 2                        New Zealand Police                       4d ago,at
# 3  Kew Pacific Island Early Learning Centre                       1h ago,at
# 4                                       NaN    4d ago,at,Private Advertiser
#
#                                                    5       location  \
# 0  classification: Administration & Office Suppor...  Bay of Plenty
# 1  classification: Administration & Office Suppor...  Bay of Plenty
# 2  classification: Administration & Office Suppor...       Auckland
# 3  classification: Administration & Office Suppor...      Southland
# 4  classification: Administration & Office Suppor...     Canterbury
#
#            area                                  subclassification  \
# 0      Tauranga   Administration & Office SupportAdministration...
# 1      Tauranga   Administration & Office SupportAdministration...
# 2       unknown   Administration & Office SupportAdministration...
# 3  Invercargill   Administration & Office SupportAdministration...
# 4  Christchurch   Administration & Office SupportAdministration...
#
#                   classification   salary posted time         featured at
# 0              Office Management  unknown    Featured  Private Advertiser
# 1                  Receptionists  unknown    Featured                None
# 2                          Other  unknown      4d ago                None
# 3      Administrative Assistants  unknown      1h ago                None
# 4  Client & Sales Administration  unknown      4d ago  Private Advertiser

# %%
nzAdmin.drop(5, axis = 1, inplace=True)

# %%
nzAdmin.drop(4, axis = 1, inplace = True)
nzAdmin.head()
# Out:
#    index                                     0  \
# 0      1                         Administrator
# 1      2                          Receptionist
# 2      3          Prosecutions Support Officer
# 3      4  Early Childhood Centre Administrator
# 4      5        Business Support Administrator
#
#                                                    1  \
# 0  https://www.seek.co.nz/job/50582301?type=promo...
# 1  https://www.seek.co.nz/job/50620889?type=promo...
# 2  https://www.seek.co.nz/job/50622169?type=stand...
# 3  https://www.seek.co.nz/job/50639620?type=stand...
# 4  https://www.seek.co.nz/job/50622432?type=stand...
#
#                                           2       location          area  \
# 0                                       NaN  Bay of Plenty      Tauranga
# 1                      Avenues Orthodontics  Bay of Plenty      Tauranga
# 2                        New Zealand Police       Auckland       unknown
# 3  Kew Pacific Island Early Learning Centre      Southland  Invercargill
# 4                                       NaN     Canterbury  Christchurch
#
#                                    subclassification  \
# 0   Administration & Office SupportAdministration...
# 1   Administration & Office SupportAdministration...
# 2   Administration & Office SupportAdministration...
# 3   Administration & Office SupportAdministration...
# 4   Administration & Office SupportAdministration...
#
#                   classification   salary posted time         featured at
# 0              Office Management  unknown    Featured  Private Advertiser
# 1                  Receptionists  unknown    Featured                None
# 2                          Other  unknown      4d ago                None
# 3      Administrative Assistants  unknown      1h ago                None
# 4  Client & Sales Administration  unknown      4d ago  Private Advertiser

# %%
nzAdmin['featured at'].isna().sum()
# Out:
# 2686

# %%
nzAdmin['featured at'].fillna('unknown', inplace=True)

# %%
nzAdmin[['classification1', 'classification2', 'classification3']]=nzAdmin['subclassification'].str.split('&', n=2, expand=True)

# %%
nzAdmin.head()
# Out:
#    index                                     0  \
# 0      1                         Administrator
# 1      2                          Receptionist
# 2      3          Prosecutions Support Officer
# 3      4  Early Childhood Centre Administrator
# 4      5        Business Support Administrator
#
#                                                    1  \
# 0  https://www.seek.co.nz/job/50582301?type=promo...
# 1  https://www.seek.co.nz/job/50620889?type=promo...
# 2  https://www.seek.co.nz/job/50622169?type=stand...
# 3  https://www.seek.co.nz/job/50639620?type=stand...
# 4  https://www.seek.co.nz/job/50622432?type=stand...
#
#                                           2       location          area  \
# 0                                       NaN  Bay of Plenty      Tauranga
# 1                      Avenues Orthodontics  Bay of Plenty      Tauranga
# 2                        New Zealand Police       Auckland       unknown
# 3  Kew Pacific Island Early Learning Centre      Southland  Invercargill
# 4                                       NaN     Canterbury  Christchurch
#
#                                    subclassification  \
# 0   Administration & Office SupportAdministration...
# 1   Administration & Office SupportAdministration...
# 2   Administration & Office SupportAdministration...
# 3   Administration & Office SupportAdministration...
# 4   Administration & Office SupportAdministration...
#
#                   classification   salary posted time         featured at  \
# 0              Office Management  unknown    Featured  Private Advertiser
# 1                  Receptionists  unknown    Featured             unknown
# 2                          Other  unknown      4d ago             unknown
# 3      Administrative Assistants  unknown      1h ago             unknown
# 4  Client & Sales Administration  unknown      4d ago  Private Advertiser
#
#     classification1                 classification2  classification3
# 0   Administration    Office SupportAdministration    Office Support
# 1   Administration    Office SupportAdministration    Office Support
# 2   Administration    Office SupportAdministration    Office Support
# 3   Administration    Office SupportAdministration    Office Support
# 4   Administration    Office SupportAdministration    Office Support

# %%
nzAdmin.rename(columns = {0:'Job title', 1:'website', 2:'company name'}, inplace = True)

# %%
nzAdmin.drop('subclassification', axis = 1, inplace=True)

# %%
nzAdmin.head()
# Out:
#    index                             Job title  \
# 0      1                         Administrator
# 1      2                          Receptionist
# 2      3          Prosecutions Support Officer
# 3      4  Early Childhood Centre Administrator
# 4      5        Business Support Administrator
#
#                                              website  \
# 0  https://www.seek.co.nz/job/50582301?type=promo...
# 1  https://www.seek.co.nz/job/50620889?type=promo...
# 2  https://www.seek.co.nz/job/50622169?type=stand...
# 3  https://www.seek.co.nz/job/50639620?type=stand...
# 4  https://www.seek.co.nz/job/50622432?type=stand...
#
#                                company name       location          area  \
# 0                                       NaN  Bay of Plenty      Tauranga
# 1                      Avenues Orthodontics  Bay of Plenty      Tauranga
# 2                        New Zealand Police       Auckland       unknown
# 3  Kew Pacific Island Early Learning Centre      Southland  Invercargill
# 4                                       NaN     Canterbury  Christchurch
#
#                   classification   salary posted time         featured at  \
# 0              Office Management  unknown    Featured  Private Advertiser
# 1                  Receptionists  unknown    Featured             unknown
# 2                          Other  unknown      4d ago             unknown
# 3      Administrative Assistants  unknown      1h ago             unknown
# 4  Client & Sales Administration  unknown      4d ago  Private Advertiser
#
#     classification1                 classification2  classification3
# 0   Administration    Office SupportAdministration    Office Support
# 1   Administration    Office SupportAdministration    Office Support
# 2   Administration    Office SupportAdministration    Office Support
# 3   Administration    Office SupportAdministration    Office Support
# 4   Administration    Office SupportAdministration    Office Support

# %%
nzAdmin[['classification1', 'classification2', 'classification3']].fillna('unknown')
# Out:
#        classification1                 classification2  classification3
# 0      Administration    Office SupportAdministration    Office Support
# 1      Administration    Office SupportAdministration    Office Support
# 2      Administration    Office SupportAdministration    Office Support
# 3      Administration    Office SupportAdministration    Office Support
# 4      Administration    Office SupportAdministration    Office Support
# ...                ...                             ...              ...
# 2703   Administration    Office SupportAdministration    Office Support
# 2704           unknown                         unknown          unknown
# 2705           unknown                         unknown          unknown
# 2706           unknown                         unknown          unknown
# 2707   Administration    Office SupportAdministration    Office Support
#
# [2708 rows x 3 columns]

# %%
## merge company name with featured at 
nzAdmin.loc[nzAdmin['company name'] == None, 'company name'] = nzAdmin['featured at']

# %%
nzAdmin.head()
# Out:
#    index                             Job title  \
# 0      1                         Administrator
# 1      2                          Receptionist
# 2      3          Prosecutions Support Officer
# 3      4  Early Childhood Centre Administrator
# 4      5        Business Support Administrator
#
#                                              website  \
# 0  https://www.seek.co.nz/job/50582301?type=promo...
# 1  https://www.seek.co.nz/job/50620889?type=promo...
# 2  https://www.seek.co.nz/job/50622169?type=stand...
# 3  https://www.seek.co.nz/job/50639620?type=stand...
# 4  https://www.seek.co.nz/job/50622432?type=stand...
#
#                                company name       location          area  \
# 0                                       NaN  Bay of Plenty      Tauranga
# 1                      Avenues Orthodontics  Bay of Plenty      Tauranga
# 2                        New Zealand Police       Auckland       unknown
# 3  Kew Pacific Island Early Learning Centre      Southland  Invercargill
# 4                                       NaN     Canterbury  Christchurch
#
#                   classification   salary posted time         featured at  \
# 0              Office Management  unknown    Featured  Private Advertiser
# 1                  Receptionists  unknown    Featured             unknown
# 2                          Other  unknown      4d ago             unknown
# 3      Administrative Assistants  unknown      1h ago             unknown
# 4  Client & Sales Administration  unknown      4d ago  Private Advertiser
#
#     classification1                 classification2  classification3
# 0   Administration    Office SupportAdministration    Office Support
# 1   Administration    Office SupportAdministration    Office Support
# 2   Administration    Office SupportAdministration    Office Support
# 3   Administration    Office SupportAdministration    Office Support
# 4   Administration    Office SupportAdministration    Office Support

# %%
nzAdmin['company name'].fillna(nzAdmin['featured at'], inplace = True)

# %%
nzAdmin.head()
# Out:
#    index                             Job title  \
# 0      1                         Administrator
# 1      2                          Receptionist
# 2      3          Prosecutions Support Officer
# 3      4  Early Childhood Centre Administrator
# 4      5        Business Support Administrator
#
#                                              website  \
# 0  https://www.seek.co.nz/job/50582301?type=promo...
# 1  https://www.seek.co.nz/job/50620889?type=promo...
# 2  https://www.seek.co.nz/job/50622169?type=stand...
# 3  https://www.seek.co.nz/job/50639620?type=stand...
# 4  https://www.seek.co.nz/job/50622432?type=stand...
#
#                                company name       location          area  \
# 0                        Private Advertiser  Bay of Plenty      Tauranga
# 1                      Avenues Orthodontics  Bay of Plenty      Tauranga
# 2                        New Zealand Police       Auckland       unknown
# 3  Kew Pacific Island Early Learning Centre      Southland  Invercargill
# 4                        Private Advertiser     Canterbury  Christchurch
#
#                   classification   salary posted time         featured at  \
# 0              Office Management  unknown    Featured  Private Advertiser
# 1                  Receptionists  unknown    Featured             unknown
# 2                          Other  unknown      4d ago             unknown
# 3      Administrative Assistants  unknown      1h ago             unknown
# 4  Client & Sales Administration  unknown      4d ago  Private Advertiser
#
#     classification1                 classification2  classification3
# 0   Administration    Office SupportAdministration    Office Support
# 1   Administration    Office SupportAdministration    Office Support
# 2   Administration    Office SupportAdministration    Office Support
# 3   Administration    Office SupportAdministration    Office Support
# 4   Administration    Office SupportAdministration    Office Support

# %%
nzAdmin.drop('featured at', axis = 1, inplace = True)

# %%
nzAdmin
# Out:
#       index                             Job title  \
# 0         1                         Administrator
# 1         2                          Receptionist
# 2         3          Prosecutions Support Officer
# 3         4  Early Childhood Centre Administrator
# 4         5        Business Support Administrator
# ...     ...                                   ...
# 2703   2704                   Key Account Manager
# 2704   2705                   Executive Assistant
# 2705   2706                Temporary Office Roles
# 2706   2707                Temporary Office Roles
# 2707   2708                   Executive Assistant
#
#                                                 website  \
# 0     https://www.seek.co.nz/job/50582301?type=promo...
# 1     https://www.seek.co.nz/job/50620889?type=promo...
# 2     https://www.seek.co.nz/job/50622169?type=stand...
# 3     https://www.seek.co.nz/job/50639620?type=stand...
# 4     https://www.seek.co.nz/job/50622432?type=stand...
# ...                                                 ...
# 2703  https://www.seek.co.nz/job/50490062?type=stand...
# 2704  https://www.seek.co.nz/job/50488000?type=stand...
# 2705  https://www.seek.co.nz/job/50524865?type=stand...
# 2706  https://www.seek.co.nz/job/50477118?type=stand...
# 2707  https://www.seek.co.nz/job/50496571?type=stand...
#
#                                   company name       location  \
# 0                           Private Advertiser  Bay of Plenty
# 1                         Avenues Orthodontics  Bay of Plenty
# 2                           New Zealand Police       Auckland
# 3     Kew Pacific Island Early Learning Centre      Southland
# 4                           Private Advertiser     Canterbury
# ...                                        ...            ...
# 2703                     Hays Talent Solutions       Auckland
# 2704                    one eighty recruitment     Wellington
# 2705                     Asset Recruitment Ltd        Waikato
# 2706                     Asset Recruitment Ltd        Waikato
# 2707                    Alpha Recruitment - NZ     Wellington
#
#                     area                 classification  \
# 0               Tauranga              Office Management
# 1               Tauranga                  Receptionists
# 2                unknown                          Other
# 3           Invercargill      Administrative Assistants
# 4           Christchurch  Client & Sales Administration
# ...                  ...                            ...
# 2703    Auckland Central  Client & Sales Administration
# 2704  Wellington Central                        unknown
# 2705            Hamilton                        unknown
# 2706            Hamilton                        unknown
# 2707             unknown           PA, EA & Secretarial
#
#                            salary posted time   classification1  \
# 0                         unknown    Featured   Administration
# 1                         unknown    Featured   Administration
# 2                         unknown      4d ago   Administration
# 3                         unknown      1h ago   Administration
# 4                         unknown      4d ago   Administration
# ...                           ...         ...               ...
# 2703                      unknown     27d ago   Administration
# 2704      Competitive hourly rate     27d ago           unknown
# 2705  Competitive hourly rates $$     20d ago           unknown
# 2706  Competitive hourly rates $$     28d ago           unknown
# 2707                      unknown     26d ago   Administration
#
#                      classification2  classification3
# 0      Office SupportAdministration    Office Support
# 1      Office SupportAdministration    Office Support
# 2      Office SupportAdministration    Office Support
# 3      Office SupportAdministration    Office Support
# 4      Office SupportAdministration    Office Support
# ...                              ...              ...
# 2703   Office SupportAdministration    Office Support
# 2704                            None             None
# 2705                            None             None
# 2706                            None             None
# 2707   Office SupportAdministration    Office Support
#
# [2708 rows x 12 columns]

# %%
nzAdmin['posted time'] = nzAdmin['posted time'].str.extract('(\d+[a-z])')

# %%
nzAdmin
# Out:
#       index                             Job title  \
# 0         1                         Administrator
# 1         2                          Receptionist
# 2         3          Prosecutions Support Officer
# 3         4  Early Childhood Centre Administrator
# 4         5        Business Support Administrator
# ...     ...                                   ...
# 2703   2704                   Key Account Manager
# 2704   2705                   Executive Assistant
# 2705   2706                Temporary Office Roles
# 2706   2707                Temporary Office Roles
# 2707   2708                   Executive Assistant
#
#                                                 website  \
# 0     https://www.seek.co.nz/job/50582301?type=promo...
# 1     https://www.seek.co.nz/job/50620889?type=promo...
# 2     https://www.seek.co.nz/job/50622169?type=stand...
# 3     https://www.seek.co.nz/job/50639620?type=stand...
# 4     https://www.seek.co.nz/job/50622432?type=stand...
# ...                                                 ...
# 2703  https://www.seek.co.nz/job/50490062?type=stand...
# 2704  https://www.seek.co.nz/job/50488000?type=stand...
# 2705  https://www.seek.co.nz/job/50524865?type=stand...
# 2706  https://www.seek.co.nz/job/50477118?type=stand...
# 2707  https://www.seek.co.nz/job/50496571?type=stand...
#
#                                   company name       location  \
# 0                           Private Advertiser  Bay of Plenty
# 1                         Avenues Orthodontics  Bay of Plenty
# 2                           New Zealand Police       Auckland
# 3     Kew Pacific Island Early Learning Centre      Southland
# 4                           Private Advertiser     Canterbury
# ...                                        ...            ...
# 2703                     Hays Talent Solutions       Auckland
# 2704                    one eighty recruitment     Wellington
# 2705                     Asset Recruitment Ltd        Waikato
# 2706                     Asset Recruitment Ltd        Waikato
# 2707                    Alpha Recruitment - NZ     Wellington
#
#                     area                 classification  \
# 0               Tauranga              Office Management
# 1               Tauranga                  Receptionists
# 2                unknown                          Other
# 3           Invercargill      Administrative Assistants
# 4           Christchurch  Client & Sales Administration
# ...                  ...                            ...
# 2703    Auckland Central  Client & Sales Administration
# 2704  Wellington Central                        unknown
# 2705            Hamilton                        unknown
# 2706            Hamilton                        unknown
# 2707             unknown           PA, EA & Secretarial
#
#                            salary posted time   classification1  \
# 0                         unknown         NaN   Administration
# 1                         unknown         NaN   Administration
# 2                         unknown          4d   Administration
# 3                         unknown          1h   Administration
# 4                         unknown          4d   Administration
# ...                           ...         ...               ...
# 2703                      unknown         27d   Administration
# 2704      Competitive hourly rate         27d           unknown
# 2705  Competitive hourly rates $$         20d           unknown
# 2706  Competitive hourly rates $$         28d           unknown
# 2707                      unknown         26d   Administration
#
#                      classification2  classification3
# 0      Office SupportAdministration    Office Support
# 1      Office SupportAdministration    Office Support
# 2      Office SupportAdministration    Office Support
# 3      Office SupportAdministration    Office Support
# 4      Office SupportAdministration    Office Support
# ...                              ...              ...
# 2703   Office SupportAdministration    Office Support
# 2704                            None             None
# 2705                            None             None
# 2706                            None             None
# 2707   Office SupportAdministration    Office Support
#
# [2708 rows x 12 columns]

# %%
nzAdmin['posted time'].fillna('unknown', inplace=True)

# %%
## define column type 
nzAdmin['posted time'] = nzAdmin['posted time'].astype('string')

# %%
def posted_time(x):
    if x == None:
        return 'unknown'
    if 'd' in x:
        return -int(x[:-1])
    if 'm' in x:
        return -(int(x[:-1])*30)
    else:
        return 0

# %%
nzAdmin['posted time'] = nzAdmin['posted time'].apply(posted_time)

# %%
nzAdmin['posted time']
# Out:
# 0        0
# 1        0
# 2       -4
# 3        0
# 4       -4
#         ..
# 2703   -27
# 2704   -27
# 2705   -20
# 2706   -28
# 2707   -26
# Name: posted time, Length: 2708, dtype: int64

# %%
## check the salary format 
nzAdmin[nzAdmin['salary'].str.contains('\d', na=False)]['salary']
# Out:
# 12                           $20 per hour
# 17                  $20 - $24.99 per hour
# 23                    $19 to $22 per hour
# 25                  $20 - $24.99 per hour
# 36                  $20 - $24.99 per hour
#                       ...
# 683     $35 - $40 p.h. + + 8% Holiday Pay
# 695                             Circa 50k
# 1936     $24 - $28 p.h.  + 8% Holiday Pay
# 1937    $35 - $40 p.h. + + 8% Holiday Pay
# 1949                            Circa 50k
# Name: salary, Length: 96, dtype: object

# %%
nzAdmin[nzAdmin['salary'].str.contains('\dk', na=False)]['salary']
# Out:
# 306                                      $75k - $85k p.a.
# 442                    $60k-$70k depending on experience!
# 473     $60 - $65k + Career Progression to QS / leader...
# 644                     $50k - $65k p.a. + plus kiwisaver
# 650                                        $70-$80k+Super
# 663                                     $70-75k per annum
# 695                                             Circa 50k
# 1949                                            Circa 50k
# Name: salary, dtype: object

# %%
nzAdmin['salary'] = nzAdmin[nzAdmin['salary'].str.contains('\d', na=False)]['salary'].str.replace(' to ', '-', regex=True)

# %%
nzAdmin[nzAdmin['salary'].str.contains('\d%', na=False)]['salary'].head(100)
# Out:
# 201                        8% holiday pay
# 311           $24 - $25 + 8% holiday pay!
# 384       $30 - $38 p.h. + 8% Holiday Pay
# 403        Up-$23 p.h. + + 8% Holiday Pay
# 458       $27 - $33 p.h. + 8% holiday pay
# 503          Up-$27 p.h. + 8% Holiday Pay
# 536       $21 - $25 p.h. + 8% Holiday Pay
# 578          Up-$35 p.h. + 8% Holiday Pay
# 579       $21 - $22 p.h. + 8% Holiday Pay
# 682      $24 - $28 p.h.  + 8% Holiday Pay
# 683     $35 - $40 p.h. + + 8% Holiday Pay
# 1936     $24 - $28 p.h.  + 8% Holiday Pay
# 1937    $35 - $40 p.h. + + 8% Holiday Pay
# Name: salary, dtype: object

# %%
nzAdmin['holiday pay'] = nzAdmin['salary'].str.extract('(\d+%)')

# %%
nzAdmin.head()
# Out:
#    index                             Job title  \
# 0      1                         Administrator
# 1      2                          Receptionist
# 2      3          Prosecutions Support Officer
# 3      4  Early Childhood Centre Administrator
# 4      5        Business Support Administrator
#
#                                              website  \
# 0  https://www.seek.co.nz/job/50582301?type=promo...
# 1  https://www.seek.co.nz/job/50620889?type=promo...
# 2  https://www.seek.co.nz/job/50622169?type=stand...
# 3  https://www.seek.co.nz/job/50639620?type=stand...
# 4  https://www.seek.co.nz/job/50622432?type=stand...
#
#                                company name       location          area  \
# 0                        Private Advertiser  Bay of Plenty      Tauranga
# 1                      Avenues Orthodontics  Bay of Plenty      Tauranga
# 2                        New Zealand Police       Auckland       unknown
# 3  Kew Pacific Island Early Learning Centre      Southland  Invercargill
# 4                        Private Advertiser     Canterbury  Christchurch
#
#                   classification salary  posted time   classification1  \
# 0              Office Management    NaN            0   Administration
# 1                  Receptionists    NaN            0   Administration
# 2                          Other    NaN           -4   Administration
# 3      Administrative Assistants    NaN            0   Administration
# 4  Client & Sales Administration    NaN           -4   Administration
#
#                   classification2  classification3 holiday pay
# 0   Office SupportAdministration    Office Support         NaN
# 1   Office SupportAdministration    Office Support         NaN
# 2   Office SupportAdministration    Office Support         NaN
# 3   Office SupportAdministration    Office Support         NaN
# 4   Office SupportAdministration    Office Support         NaN

# %%
nzAdmin['holiday pay'].unique()
# Out:
# array([nan, '8%'], dtype=object)

# %%
nzAdmin['holiday pay'].isna().sum()
# Out:
# 2695

# %%
nzAdmin[nzAdmin['salary'].str.contains('\dk', na=False)]['salary']
# Out:
# 306                                    $75k - $85k p.a.
# 442                  $60k-$70k depending on experience!
# 473     $60 - $65k + Career Progression-QS / leadership
# 644                   $50k - $65k p.a. + plus kiwisaver
# 650                                      $70-$80k+Super
# 663                                   $70-75k per annum
# 695                                           Circa 50k
# 1949                                          Circa 50k
# Name: salary, dtype: object

# %%
nzAdmin['salary'] = nzAdmin[nzAdmin['salary'].str.contains('\d', na=False)]['salary'].str.replace('\d\%', '', regex = True)

# %%
nzAdmin['salary']=nzAdmin[nzAdmin['salary'].str.contains('\d', na=False)]['salary'].str.replace(',', '', regex=True)

# %%
nzAdmin[nzAdmin['salary'].str.contains('\d', na=False)]['salary'].head(100)
# Out:
# 12                         $20 per hour
# 17                $20 - $24.99 per hour
# 23                     $19-$22 per hour
# 25                $20 - $24.99 per hour
# 36                $20 - $24.99 per hour
#                      ...
# 683     $35 - $40 p.h. + +  Holiday Pay
# 695                           Circa 50k
# 1936     $24 - $28 p.h.  +  Holiday Pay
# 1937    $35 - $40 p.h. + +  Holiday Pay
# 1949                          Circa 50k
# Name: salary, Length: 95, dtype: object

# %%
nzAdmin['salary'].fillna('unknown')
# Out:
# 0       unknown
# 1       unknown
# 2       unknown
# 3       unknown
# 4       unknown
#          ...
# 2703    unknown
# 2704    unknown
# 2705    unknown
# 2706    unknown
# 2707    unknown
# Name: salary, Length: 2708, dtype: object

# %%
nzAdmin[nzAdmin['salary'].str.contains('\d', na=False)]['salary'].head(100)
# Out:
# 12                         $20 per hour
# 17                $20 - $24.99 per hour
# 23                     $19-$22 per hour
# 25                $20 - $24.99 per hour
# 36                $20 - $24.99 per hour
#                      ...
# 683     $35 - $40 p.h. + +  Holiday Pay
# 695                           Circa 50k
# 1936     $24 - $28 p.h.  +  Holiday Pay
# 1937    $35 - $40 p.h. + +  Holiday Pay
# 1949                          Circa 50k
# Name: salary, Length: 95, dtype: object

# %%
nzAdmin[['low salary', 'high salary']]=nzAdmin['salary'].str.split('-', n=1, expand=True).fillna('unknown')

# %%
nzAdmin[nzAdmin['high salary'].str.contains('\d', na=False)]['high salary'].head(100)
# Out:
# 17                      $24.99 per hour
# 23                         $22 per hour
# 25                      $24.99 per hour
# 36                      $24.99 per hour
# 42                               $49999
#                      ...
# 679      $55000 depending on experience
# 682            $28 p.h.  +  Holiday Pay
# 683           $40 p.h. + +  Holiday Pay
# 1936           $28 p.h.  +  Holiday Pay
# 1937          $40 p.h. + +  Holiday Pay
# Name: high salary, Length: 83, dtype: object

# %%
nzAdmin[nzAdmin['salary'].str.contains('\d', na=False)][['salary', 'low salary', 'high salary']]
# Out:
#                                salary    low salary  \
# 12                       $20 per hour  $20 per hour
# 17              $20 - $24.99 per hour          $20
# 23                   $19-$22 per hour           $19
# 25              $20 - $24.99 per hour          $20
# 36              $20 - $24.99 per hour          $20
# ...                               ...           ...
# 683   $35 - $40 p.h. + +  Holiday Pay          $35
# 695                         Circa 50k     Circa 50k
# 1936   $24 - $28 p.h.  +  Holiday Pay          $24
# 1937  $35 - $40 p.h. + +  Holiday Pay          $35
# 1949                        Circa 50k     Circa 50k
#
#                      high salary
# 12                       unknown
# 17               $24.99 per hour
# 23                  $22 per hour
# 25               $24.99 per hour
# 36               $24.99 per hour
# ...                          ...
# 683    $40 p.h. + +  Holiday Pay
# 695                      unknown
# 1936    $28 p.h.  +  Holiday Pay
# 1937   $40 p.h. + +  Holiday Pay
# 1949                     unknown
#
# [95 rows x 3 columns]

# %%
nzAdmin['low salary']=nzAdmin['low salary'].str.extract('(\d+\.\d+|\d+ \d+|\d+k|\d+)')
nzAdmin['high salary']=nzAdmin['high salary'].str.extract('(\d+\.\d+|\d+ \d+|\d+k|\d+)')

# %%
nzAdmin[nzAdmin['low salary'].str.contains('\d', na=False)]['low salary'].unique()
# Out:
# array(['20', '19', '40000', '25', '60 000', '20.00', '55000', '21',
#        '50000', '45000', '48835', '24', '22', '75000', '75k', '30', '45',
#        '69726', '60k', '22.00', '27', '60', '35', '60000', '40', '18.50',
#        '25.5', '48000', '50k', '70'], dtype=object)

# %%
nzAdmin[nzAdmin['salary'].str.contains('\dk', na=False)][['salary', 'low salary', 'high salary']]
# Out:
#                                                salary low salary high salary
# 306                                  $75k - $85k p.a.        75k         85k
# 442                $60k-$70k depending on experience!        60k         70k
# 473   $60 - $65k + Career Progression-QS / leadership         60         65k
# 644                 $50k - $65k p.a. + plus kiwisaver        50k         65k
# 650                                    $70-$80k+Super         70         80k
# 663                                 $70-75k per annum         70         75k
# 695                                         Circa 50k        50k         NaN
# 1949                                        Circa 50k        50k         NaN

# %%
nzAdmin['low salary'] = nzAdmin[nzAdmin['low salary'].str.contains('\d', na=False)]['low salary'].str.replace(' ', '', regex=True)
nzAdmin['high salary'] = nzAdmin[nzAdmin['high salary'].str.contains('\d', na=False)]['high salary'].str.replace(' ', '', regex=True)

# %%
nzAdmin[nzAdmin['salary'].str.contains('\dk', na=False)][['salary', 'low salary', 'high salary']]
# Out:
#                                                salary low salary high salary
# 306                                  $75k - $85k p.a.        75k         85k
# 442                $60k-$70k depending on experience!        60k         70k
# 473   $60 - $65k + Career Progression-QS / leadership         60         65k
# 644                 $50k - $65k p.a. + plus kiwisaver        50k         65k
# 650                                    $70-$80k+Super         70         80k
# 663                                 $70-75k per annum         70         75k
# 695                                         Circa 50k        50k         NaN
# 1949                                        Circa 50k        50k         NaN

# %%
nzAdmin.loc[nzAdmin['high salary'].str.contains('\d+k', na=False) & ~nzAdmin['low salary'].str.contains('k', na=False), 'low salary'] = nzAdmin[nzAdmin['high salary'].str.contains('\d+k', na=False) & ~nzAdmin['low salary'].str.contains('k', na=False)]['low salary'].str.replace('0', '0k')

# %%
nzAdmin[nzAdmin['salary'].str.contains('\dk', na=False)][['salary', 'low salary', 'high salary']]
# Out:
#                                                salary low salary high salary
# 306                                  $75k - $85k p.a.        75k         85k
# 442                $60k-$70k depending on experience!        60k         70k
# 473   $60 - $65k + Career Progression-QS / leadership        60k         65k
# 644                 $50k - $65k p.a. + plus kiwisaver        50k         65k
# 650                                    $70-$80k+Super        70k         80k
# 663                                 $70-75k per annum        70k         75k
# 695                                         Circa 50k        50k         NaN
# 1949                                        Circa 50k        50k         NaN

# %%
nzAdmin['low salary'] = nzAdmin[nzAdmin['low salary'].str.contains('\d+k', na=False)]['low salary'].str.replace('k', '000', regex=True)
nzAdmin['high salary'] = nzAdmin[nzAdmin['high salary'].str.contains('\d+k', na=False)]['high salary'].str.replace('k', '000', regex=True)

# %%
nzAdmin.loc[nzAdmin['low salary'] == 'unknown', 'low salary'] = nzAdmin['high salary']
nzAdmin.loc[nzAdmin['high salary'] == 'unknown', 'high salary'] = nzAdmin['low salary']

# %%
nzAdmin['low salary'].fillna('unknown', inplace=True)
nzAdmin['high salary'].fillna('unknown', inplace=True)
nzAdmin.loc[nzAdmin['low salary'] == 'unknown', 'low salary'] = nzAdmin['high salary']
nzAdmin.loc[nzAdmin['high salary'] == 'unknown', 'high salary'] = nzAdmin['low salary']

# %%
## low salary add k 
def add_k(x, y):
    if x.isnumeric() and y.isnumeric():
        x = float(x)
        y = float(y)
        if x/y >= 1000:
            y=y*1000
        else:
            return y

# %%
nzAdmin['low salary'] =nzAdmin.apply(lambda x: add_k(x['high salary'], x['low salary']), axis=1)

# %%
nzAdmin[nzAdmin['salary'].str.contains('\dk', na=False)][['salary', 'low salary', 'high salary']]
# Out:
#                                                salary  low salary high salary
# 306                                  $75k - $85k p.a.     75000.0       85000
# 442                $60k-$70k depending on experience!     60000.0       70000
# 473   $60 - $65k + Career Progression-QS / leadership     60000.0       65000
# 644                 $50k - $65k p.a. + plus kiwisaver     50000.0       65000
# 650                                    $70-$80k+Super     70000.0       80000
# 663                                 $70-75k per annum     70000.0       75000
# 695                                         Circa 50k     50000.0       50000
# 1949                                        Circa 50k     50000.0       50000
